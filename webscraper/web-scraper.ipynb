# %% [markdown]
# # Web Scraper

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from typing import List, Dict
import pandas as pd
import os
import openpyxl
import time

# %%
class ScraperBase(object):
    def __init__(self, webdriver: webdriver, name: str, web_url: str) -> None:
        self._webdriver = webdriver
        self._name = name
        self._web_url = web_url
        self._storage = {}
    
    def _search_desired_item(self) -> None:
        raise NotImplementedError
    
    def _get_all_product_links(self) -> List[str]:
        raise NotImplementedError
    
    def _parse_data(self, link: str) -> None:
        raise NotImplementedError
    
    def run(self) -> Dict:
        start_time = time.time()
        self._webdriver.get(self._web_url)
        self._search_desired_item()
        links = self._get_all_product_links()
        print("Num of links: %d" % len(links))
        for i in range(len(links)):
            self._parse_data(link=links[i])
            print("Progress: %d/%d" % (i + 1, len(links)), end='\r' )
        print("Progress: %d/%d" % (len(links), len(links)))
        print("Total time elapsed: %.2fs" % (time.time() - start_time))
        return self._storage

# %%
class EbayScraper(ScraperBase):
    def __init__(self, webdriver: webdriver, name: str, web_url: str) -> None:
        super(EbayScraper, self).__init__(webdriver=webdriver, name=name, web_url=web_url)

    def _search_desired_item(self) -> None:
        search_bar = self._webdriver.find_element_by_xpath('//*[@id="gh-ac"]')
        search_bar.send_keys("laptop", Keys.ENTER)
        refurbished_items = self._webdriver.find_element_by_xpath(
            '//*[@id="x-refine__group__2"]/ul/li[3]/div/a/div/div/span[1]')
        refurbished_items.click()
        non_auction_items = self._webdriver.find_element_by_xpath(
            '//*[@id="s0-14-11-5-1[0]"]/div[2]/div/div/ul/li[3]/a/h2')
        non_auction_items.click()
        self._webdriver.get(self._webdriver.current_url + "&_ipg=200")
    
    def _get_all_product_links(self) -> List[str]:
        link_container = self._webdriver.find_element_by_xpath(
            '//*[@id="srp-river-results"]/ul').find_elements_by_tag_name("a")
        links = []
        for link in link_container:
            links.append(link.get_attribute("href"))
        links = list(set(links))
        return links
    
    def _parse_data(self, link: str) -> None:
        self._webdriver.get(link)
        product_id = str(len(self._storage.keys()) + 1)
        try:
            product_title = self._webdriver.find_element_by_xpath('//*[@id="itemTitle"]').text.lower()
            product_cost = self._webdriver.find_element_by_xpath('//*[@id="prcIsum"]').get_attribute("content")
            specs = self._webdriver.find_element_by_xpath(
                '//*[@id="viTabs_0_is"]/div/table').find_elements_by_tag_name("tr")
            try:
                product_desc = self._webdriver.find_element_by_xpath(
                    '//*[@id="ds_div"]/font/font/font/font/font/font/font/font/font/ul/li/p').text.lower()
            except NoSuchElementException:
                product_desc = ""
            self._storage[product_id] = {"Title": product_title, 'Link': link, "Price": product_cost, 
                                         "Description": product_desc}
            for spec in specs:
                spec_titles = spec.find_elements_by_class_name("attrLabels")
                spec_values = spec.find_elements_by_tag_name("span")
                if len(spec_titles) == len(spec_values):
                    for j in range(len(spec_titles)):
                        self._storage[product_id][spec_titles[j].text.strip().capitalize()[: -1]] = \
                            spec_values[j].text.strip().lower()
        except NoSuchElementException:
            print("\n\rParsing failed, link: %s" % link)
            self._storage.pop(product_id, None)

# %%
class ReebeloScraper(ScraperBase):
    def __init__(self, webdriver: webdriver, name: str, web_url: str) -> None:
        super(ReebeloScraper, self).__init__(webdriver=webdriver, name=name, web_url=web_url)
    
    def _search_desired_item(self) -> None:
        search_bar = self._webdriver.find_element_by_xpath('//*[@id="bc-sf-search-box-0"]')
        search_bar.send_keys("laptop", Keys.ENTER)
        time.sleep(3)
        self._webdriver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(1)

    def _get_all_product_links(self) -> List[str]:
        link_container = self._webdriver.find_element_by_xpath(
            '//*[@id="bc-sf-filter-products"]').find_elements_by_tag_name("a")
        links = []
        for link in link_container:
            links.append(link.get_attribute("href"))
        links = list(set(links))
        return links
    
    def _parse_data(self, link: str) -> None:
        self._webdriver.get(link)
        product_id = str(len(self._storage.keys()) + 1)
        product_title = self._webdriver.find_element_by_xpath(
            '/html/body/main/div[2]/section/div[1]/div[3]/div/'
            'div[2]/div/div[1]/form/div[1]/div[1]/h1').text.lower()
        product_cost = self._webdriver.find_element_by_xpath(
            '/html/body/main/div[2]/section/div[1]/div[3]/div/div[2]/div/div[1]/form/div[1]/div[2]/div/'
            'div[1]/span[1]/span').text[2: ]
        self._storage[product_id] = {"Title": product_title, 'Link': link, "Price": product_cost, 
                                     "Description": ""}
        try:
            view_more_btn = self._webdriver.find_element_by_class_name("cus-btn").find_element_by_tag_name("a")
            view_more_btn.click()
        except NoSuchElementException:
            pass
        try:
            specs = self._webdriver.find_element_by_class_name("table-wrapper").find_elements_by_tag_name("tr")
        except NoSuchElementException:
            specs = self._webdriver.find_element_by_class_name("custom-table").find_elements_by_tag_name("li")
            for spec in specs:
                parsed_spec = spec.text.split(":")
                if len(parsed_spec) == 2:
                    spec_title = parsed_spec[0].strip().capitalize()
                    spec_value = parsed_spec[1].strip().lower()
                    self._storage[product_id][spec_title] = spec_value
                elif len(parsed_spec) == 1:
                    pass
                else:
                    raise Exception("parsed_spec: %s" % parsed_spec)
        else:
            try:
                for spec in specs:
                    parsed_spec = spec.find_element_by_tag_name("td").text.split(":")
                    if len(parsed_spec) == 3:
                        spec_title = parsed_spec[0].strip().capitalize()
                        spec_value = parsed_spec[1].split()[0].strip().lower()
                        self._storage[product_id][spec_title] = spec_value.strip()
                        spec_title = parsed_spec[1][len(spec_value) + 2:].strip().capitalize()
                        spec_value = parsed_spec[2].strip().lower()
                    elif len(parsed_spec) == 2:
                        spec_title = parsed_spec[0].strip().capitalize()
                        spec_value = parsed_spec[1].strip().lower()
                    elif len(parsed_spec) == 1:
                        print(parsed_spec[0])
                        spec_title, spec_value = "Model", parsed_spec[0].strip().lower()
                    else:
                        raise Exception("parsed_spec: %s" % parsed_spec)
                    self._storage[product_id][spec_title] = spec_value
            except NoSuchElementException:
                print("\n\rParsing failed, link: %s" % link)
                self._storage.pop(product_id, None)

# %%
# Instantiate the webdriver
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized")
driver = webdriver.Chrome(executable_path=os.getenv("CHROMEDRIVER_PATH"), options=options)

# %%
# Instantiate all scrapers
ebay_scraper = EbayScraper(webdriver=driver, name="eBay", web_url="https://www.ebay.com.sg/")
reebelo_scraper = ReebeloScraper(webdriver=driver, name="Reebelo", web_url="https://www.reebelo.com/")

# %%
# Start scraping Ebay
ebay_storage = ebay_scraper.run()
# Out:
# Num of links: 64
# Progress: 6/64
# Parsing failed, link: https://www.ebay.com.sg/sch/i.html?_from=R40&_nkw=laptop&_sacat=0&LH_ItemCondition=2500&rt=nc&LH_BIN=1&_ipg=200&RAM%2520Size=1%252D19%2520GB&_dcat=177
# Progress: 9/64
# Parsing failed, link: https://www.ebay.com.sg/sch/i.html?_from=R40&_nkw=laptop&_sacat=0&LH_ItemCondition=2500&rt=nc&LH_BIN=1&_ipg=200&RAM%2520Size=12%2520GB&_dcat=177
# Progress: 21/64
# Parsing failed, link: https://www.ebay.com.sg/sch/i.html?_from=R40&_nkw=laptop&_sacat=0&LH_ItemCondition=2500&rt=nc&LH_BIN=1&_ipg=200&RAM%2520Size=16%2520GB&_dcat=177
# Progress: 41/64
# Parsing failed, link: https://www.ebay.com.sg/sch/i.html?_from=R40&_nkw=laptop&_sacat=0&LH_ItemCondition=2500&rt=nc&LH_BIN=1&_ipg=200&RAM%2520Size=4%2520GB&_dcat=177
# Progress: 55/64
# Parsing failed, link: https://www.ebay.com.sg/sch/i.html?_from=R40&_nkw=laptop&_sacat=0&LH_ItemCondition=2500&rt=nc&LH_BIN=1&_ipg=200&RAM%2520Size=8%2520GB&_dcat=177
# Progress: 64/64
# Total time elapsed: 164.63s

# %%
# Start scraping Reebelo
reebelo_storage = reebelo_scraper.run()
# Out:
# Num of links: 45
# Lenovo ThinkPad Yoga 370 (Silver) (TOUCHSCREEN)
# Model & OS17/45
# Model
# Installed OS
#
# Processor
# Processor
# Processor Type
# Processor Speed
# Memory
# Memory Type
# Memory Std.
# Memory Max.
# Memory Slots
# Drives / Storage
# SSD Capacity
# Display
# LED backlight
# Display Type
# Display Size
# Display Max. Res.
# Multimedia
# Integrated Camera
# Graphics
# Graphic Controller
# Audio
# Audio Controller
# Integrated Speakers
# Built in Mic
# Interfaces
# Ports - USB 3 Series Type-A
# Ports - USB 3 Series Type-C
# Ports - Audio
# HDMI Connector
# Slots / Expansions
# Card Reader
# Connectivity
# Network
# Modem
# Bluetooth
# Input
# KeyBoard
# Pointing Device
# Security
# Fingerprint Reader
# Power
# Battery Type
# Battery Runtime
# Ac Adaptor
# Number Of Cells
# Dimensions
# Width
# Height
# Depth
# Weight
# Other
# Special Features
# Lenovo ThinkPad X1 Yoga G1 (Black) (TOUCHSCREEN)
# FUJITSU Notebook LIFEBOOK E546 (Black)
# HP ZBook 15 G3 Mobile Workstation Laptop
# Progress: 45/45
# Total time elapsed: 155.24s

# %%
# Stop the webdriver
driver.quit()

# %%
ebay_storage
# Out:
# {'1': {'Title': 'dell latitude 5404 rugged extreme laptop i7-4650u16gb 1tb ssd win10 4g lte bt',
#   'Link': 'https://www.ebay.com.sg/itm/Dell-Latitude-5404-Rugged-Extreme-Laptop-i7-4650U16GB-1TB-SSD-WIN10-4G-LTE-BT/164402678993?hash=item264729ccd1%3Ag%3AseoAAOSwyKBfb021&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '1472.12',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Memory': '8gb',
#   'Model': '5404',
#   'Operating system edition': 'professional',
#   'Processor': 'intel core i7 4th gen.',
#   'Ram size': '16 gb',
#   'Release year': '2014',
#   'Type': 'notebook/laptop',
#   'Graphics processing type': 'integrated/on-board graphics',
#   'Processor speed': '2.0ghz',
#   'Features': 'triple rf - passthough, 4g lte cellular, rugged, bluetooth, backlit keyboard',
#   'Operating system': 'windows 10',
#   'Mpn': '5404',
#   'Storage type': 'ssd (solid state drive)',
#   'Series': 'latitude',
#   'Brand': 'dell',
#   'Hard drive capacity': '1 tb',
#   'Ssd capacity': '1 tb',
#   'Product line': 'latitude',
#   'Hardware connectivity': 'displayport',
#   'Processor type': 'intel core i7 4th gen.',
#   'Screen size': '14in.',
#   'Upc': 'does not apply'},
#  '2': {'Title': 'asus zenbook ux31a ultrabook 13.3" full hd i7-3517u 256gb 4gb lightweight laptop',
#   'Link': 'https://www.ebay.com.sg/itm/ASUS-Zenbook-UX31A-Ultrabook-13-3-Full-HD-i7-3517U-256GB-4GB-Lightweight-Laptop/353294278388?hash=item5241fadef4%3Ag%3Ax40AAOSwMQNfv7zv&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '649.49',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Graphics processing type': 'integrated/on-board graphics',
#   'Hard drive capacity': 'not applicable',
#   'Features': 'wi-fi, built-in webcam',
#   'Most suitable for': 'casual computing',
#   'Modified item': 'no',
#   'Ssd capacity': '256 gb',
#   'Color': 'gray',
#   'Operating system': 'windows 10',
#   'Screen size': '13.3 in full hd',
#   'Processor speed': '1.90 ghz',
#   'Brand': 'asus',
#   'Ram size': '4 gb',
#   'Non-domestic product': 'no',
#   'Type': 'notebook/laptop',
#   'Custom bundle': 'no',
#   'Model': 'asus zenbook',
#   'Processor': 'intel core i7 3rd gen.',
#   'Storage type': 'ssd (solid state drive)',
#   'Connectivity': 'usb 2.0, usb 3.0, micro-hdmi',
#   'Upc': 'does not apply'},
#  '3': {'Title': 'notebook laptop siemens simatic filed pg 6es7710-1ca31 pentium programmer',
#   'Link': 'https://www.ebay.com.sg/itm/Notebook-Laptop-SIEMENS-Simatic-Filed-PG-6ES7710-1CA31-Pentium-Programmer/324390977572?hash=item4b87358024%3Ag%3AKwIAAOSwADVeGHyv&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '1550.2',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Operating system': 'windows xp',
#   'Hard drive capacity': '40gb',
#   'Memory ram': '128mb',
#   'Ssd hard drive capacity': 'not applicable',
#   'Mpn': '6es7710-1ca31-1fa0',
#   'Product line': 'simatic',
#   'Screen size': '14,1 zoll (35,8 cm)',
#   'Model': 'filed pg',
#   'Hard drive type': 'hdd (hard disk drive)',
#   'Type': 'netbook/notebook/laptop',
#   'Ean': '7427055324890',
#   'Brand': 'siemens',
#   'Processor speed': '700mhz',
#   'Processor type': 'intel pentium iii',
#   'Processor': 'does not apply',
#   'Upc': 'does not apply',
#   'Graphic processor': 'integrated graphic'},
#  '4': {'Title': 'hp 14-cf1502sa 14" full hd laptop intel quad core i7 8565u 8gb ram 512gb ssd',
#   'Link': 'https://www.ebay.com.sg/itm/HP-14-CF1502sa-14-Full-HD-Laptop-Intel-Quad-Core-i7-8565U-8GB-RAM-512GB-SSD/293993396424?hash=item44735f38c8%3Ag%3ANQoAAOSwlSVgEfM7&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '1037.08',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Graphics processing type': 'amd radeon 530 2gb gddr5',
#   'Manufacturer warranty': 'other: see item description',
#   'Features': 'built-in microphone, built-in webcam, bluetooth, multi-touch trackpad',
#   'Memory': '8gb',
#   'Mpn': '6vk71ea#abu',
#   'Operating system': 'windows 10',
#   'Screen size': '14in',
#   'Model': 'hp 14-cf1502sa',
#   'Brand': 'hp',
#   'Type': 'notebook/laptop',
#   'Ssd capacity': '512gb',
#   'Processor type': 'intel core i7 8565u',
#   'Processor': 'intel core i7 8th gen.',
#   'Storage type': 'ssd',
#   'Color': 'silver',
#   'Upc': 'does not apply',
#   'Maximum resolution': '1920 x 1080'},
#  '5': {'Title': 'hp 15s-eq1510sa 15.6" full hd laptop amd ryzen 5 4500u 8gb ram 256 gb ssd 2020',
#   'Link': 'https://www.ebay.com.sg/itm/HP-15s-eq1510sa-15-6-Full-HD-Laptop-AMD-Ryzen-5-4500U-8GB-RAM-256-GB-SSD-2020/293993396607?hash=item44735f397f%3Ag%3Ad9cAAOSwOERf39gw&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '932.73',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Operating system': 'windows 10',
#   'Maximum resolution': '1920 x 1080',
#   'Features': 'bluetooth, built-in webcam, built-in microphone, wi-fi, multi-touch trackpad',
#   'Most suitable for': 'casual computing',
#   'Color': 'silver',
#   'Gpu': 'amd radeon graphics',
#   'Type': 'notebook/laptop',
#   'Hard drive capacity': '256 gb',
#   'Brand': 'hp',
#   'Model': 'hp 15s-eq1510sa',
#   'Storage type': 'ssd (solid state drive)',
#   'Ram size': '8 gb',
#   'Processor speed': '2.30 ghz',
#   'Screen size': '15.6 in',
#   'Ssd capacity': '256 gb',
#   'Release year': '2020',
#   'Processor': 'amd ryzen 5',
#   'Item height': '17.9',
#   'Item weight': '1.74 kg',
#   'Upc': 'does not apply',
#   'Connectivity': 'hdmi',
#   'Ean': '0195122280628'},
#  '6': {'Title': 'notebook laptop siemens simatic filed pg m 6es7712-1bb10-0ag programmer 08',
#   'Link': 'https://www.ebay.com.sg/itm/Notebook-Laptop-SIEMENS-Simatic-Filed-Pg-M-6ES7712-1BB10-0AG-Programmer-08/224250390406?hash=item34365d6786%3Ag%3AUikAAOSwX8ld4TnD&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '1416.1',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Operating system': 'windows xp',
#   'Graphic processor': 'integrated graphic',
#   'Memory ram': '128mb',
#   'Hard drive capacity': '80gb',
#   'Mpn': '6es7712-1bb10-0ag0',
#   'Product line': 'simatic',
#   'Screen size': '15 zoll (38,5 cm)',
#   'Ssd hard drive capacity': 'not applicable',
#   'Hard drive type': 'hdd (hard disk drive)',
#   'Model': 'filed pg m',
#   'Ean': '7427055325316',
#   'Type': 'netbook/notebook/laptop',
#   'Processor speed': '2ghz',
#   'Brand': 'siemens',
#   'Processor type': 'intel pentium iii',
#   'Upc': 'does not apply',
#   'Processor': 'does not apply'},
#  '7': {'Title': 'acer nitro 5 an515 15.6" full hd intel quad core i5 8gb 256gb ssd gaming laptop',
#   'Link': 'https://www.ebay.com.sg/itm/Acer-Nitro-5-AN515-15-6-Full-HD-Intel-Quad-Core-i5-8GB-256GB-SSD-Gaming-Laptop/303892254525?hash=item46c163cf3d%3Ag%3AnjsAAOSwH5dgL7c8&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '1115.62',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Screen size': 'does not apply',
#   'Ean': '4710180824445',
#   'Processor': 'does not apply',
#   'Brand': 'unbranded',
#   'Upc': 'does not apply'},
#  '8': {'Title': 'lenovo yoga s730 13.3" full hd laptop quad core i7 16gb ram 256gb ssd ultrabook',
#   'Link': 'https://www.ebay.com.sg/itm/Lenovo-YOGA-S730-13-3-Full-HD-Laptop-Quad-Core-i7-16GB-RAM-256GB-SSD-Ultrabook/303864474133?hash=item46bfbbea15%3Ag%3AD6sAAOSwGJVd7tt8&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '1074.2',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Release year': '2019',
#   'Color': 'gray',
#   'Graphics processing type': 'integrated/on-board graphics',
#   'Maximum resolution': '1920 x 1080',
#   'Features': 'backlit keyboard, built-in microphone, built-in webcam, bluetooth',
#   'Operating system': 'windows 10',
#   'Mpn': '81j0000puk',
#   'Model': 'lenovo yoga 730',
#   'Screen size': '13.3 in',
#   'Ram size': '16 gb',
#   'Brand': 'lenovo',
#   'Type': 'notebook/laptop',
#   'Processor speed': '4.60 ghz',
#   'Manufacturer colour': 'grey',
#   'Ssd capacity': '256 gb',
#   'Storage type': 'ssd (solid state drive)',
#   'Processor': 'intel core i7 8th gen.',
#   'Upc': 'does not apply',
#   'Hardware connectivity': 'usb 3.0'},
#  '9': {'Title': 'laptop computer lenovo l412 i3 4gb 120gb ssd 14 " teletrabajo (propuestas)',
#   'Link': 'https://www.ebay.com.sg/itm/Laptop-Computer-Lenovo-L412-I3-4GB-120GB-SSD-14-Teletrabajo-Propuestas/264842885124?hash=item3da9ddb804%3Ag%3AUXwAAOSwzkRd1Ayy&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '697.88',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Style': 'laptop',
#   'Manufacturer warranty': '6 months',
#   'Memory ram': '4 gb',
#   'System operating': 'windows 10',
#   'Size screen': '14"',
#   'Product non-national': "doesn't",
#   'Type unity': 'unity',
#   'Gpu': 'integrated',
#   'Capacity disk hard': '120gb',
#   'Model': 'i3-m380',
#   'Colour main': 'black',
#   'Processor': 'i3 m380',
#   'Brand': 'lenovo',
#   'Type storage': 'ssd (unit of condition solid)',
#   'Article modified': "doesn't",
#   'Capacity ssd': '120 gb',
#   'Amount of units': '1',
#   'Features': 'robust',
#   'Size of ram': '4 gb',
#   'Color': 'black',
#   'Year launch': '2018',
#   'Mpn': 'l412',
#   "Colour the manufacturer's": 'black',
#   'Type card graphic': 'integrated',
#   'Screen size': 'does not apply',
#   'Edition of the system operating': 'professional',
#   'Resolution maximum': '1280 x 768',
#   'Upc': 'does not apply',
#   'Speed of the processor': '2,53 ghz'},
#  '10': {'Title': 'hp 14-cf2503sa 14" full hd intel quad core i5-10210u 256gb ssd 4gb ram laptop',
#   'Link': 'https://www.ebay.com.sg/itm/HP-14-cf2503sa-14-Full-HD-Intel-Quad-Core-I5-10210u-256GB-SSD-4GB-RAM-Laptop/303878045975?hash=item46c08b0117%3Ag%3AXkwAAOSwIGhgEf2K&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '853.93',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Item width': '22.59 cm',
#   'Gpu': 'intel uhd graphics',
#   'Maximum resolution': '1920 x 1080',
#   'Processor speed': '1.60 ghz',
#   'Ram size': '4 gb',
#   'Processor': 'intel core i5 10th gen.',
#   'Type': 'notebook/laptop',
#   'Item height': '1.99 cm',
#   'Model': 'hp 14-cf2503sa',
#   'Graphics processing type': 'integrated/on-board graphics',
#   'Operating system': 'windows 10',
#   'Features': 'built-in microphone, built-in webcam, bluetooth',
#   'Storage type': 'ssd (solid state drive)',
#   'Mpn': '2b5w9eaabu',
#   'Brand': 'hp',
#   'Color': 'white',
#   'Ssd capacity': '256 gb',
#   'Hard drive capacity': '256 gb',
#   'Connectivity': 'hdmi, usb-c, usb 3.0, usb 3.1, gigabit ethernet',
#   'Most suitable for': 'casual computing',
#   'Item length': '32.4 cm',
#   'Release year': '2019',
#   'Screen size': '14 in',
#   'Upc': 'does not apply',
#   'Item weight': '1.47 kg',
#   'Ean': '0195161209826'},
#  '11': {'Title': 'dell latitude 14 7414 rugged extreme laptop i5-6300u 16gb 2tb sshd a-gps 4g lte',
#   'Link': 'https://www.ebay.com.sg/itm/Dell-Latitude-14-7414-Rugged-Extreme-Laptop-i5-6300U-16GB-2TB-SSHD-A-GPS-4G-LTE/164210602934?hash=item263bb6f3b6%3Ag%3ANUEAAOSwmXJb012R&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '2656.59',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Modified item': 'no',
#   'Screen size': '14in.',
#   'Custom bundle': 'no',
#   'Product line': 'latitude',
#   'Memory': '16gb',
#   'Model': '7414',
#   'Operating system edition': 'professional',
#   'Processor': 'does not apply',
#   'Type': 'notebook/laptop',
#   'Features': 'touchscreen, mobile broadband [4g lte], bluetooth, a-gps, triple rf - passthough, backlit keyboard',
#   'Processor speed': '2.30ghz',
#   'Mpn': '7414',
#   'Operating system': 'windows 10',
#   'Non-domestic product': 'no',
#   'Storage type': 'sshd (solid state hybrid drive)',
#   'Processor type': 'intel core i5 6th gen.',
#   'Brand': 'dell',
#   'Optical drive': 'none',
#   'Ssd capacity': '2tb',
#   'Release year': '2016',
#   'Hardware connectivity': 'displayport',
#   'Upc': 'does not apply'},
#  '12': {'Title': 'notebook laptop siemens simatic filed pg 6es7710-1ca31-0fb1 programming device',
#   'Link': 'https://www.ebay.com.sg/itm/Notebook-Laptop-SIEMENS-Simatic-Filed-PG-6ES7710-1CA31-0FB1-Programming-Device/224250390591?hash=item34365d683f%3Ag%3AWyoAAOSwCtFeGILH&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '1545.41',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Operating system': 'windows xp',
#   'Hard drive capacity': '20 gb',
#   'Memory ram': '128mb',
#   'Ssd hard drive capacity': 'not applicable',
#   'Mpn': '6es7710-1ca31-0fb1',
#   'Product line': 'simatic',
#   'Screen size': '14,1 zoll (35,8 cm)',
#   'Model': 'filed pg',
#   'Hard drive type': 'hdd (hard disk drive)',
#   'Type': 'netbook/notebook/laptop',
#   'Ean': '7427055324890',
#   'Brand': 'siemens',
#   'Processor speed': '700mhz',
#   'Processor type': 'intel pentium iii',
#   'Processor': 'does not apply',
#   'Upc': 'does not apply',
#   'Graphic processor': 'integrated graphic'},
#  '13': {'Title': 'linux laptop | dell latitude e6420 14" ubuntu 16.04, 8gb, 240 gb ssd, i5-2520m',
#   'Link': 'https://www.ebay.com.sg/itm/Linux-Laptop-Dell-Latitude-E6420-14-Ubuntu-16-04-8GB-240-GB-SSD-i5-2520M/222173547479?hash=item33ba934bd7%3Ag%3AI3cAAOSwEjFXdurZ&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '449.0',
#   'Description': ''},
#  '14': {'Title': 'laptop computer lenovo x230 i5 10892 5/12ft 2,6ghz 4gb ram 320gb 12,5 (',
#   'Link': 'https://www.ebay.com.sg/itm/Laptop-Computer-Lenovo-X230-I5-10892-5-12ft-2-6GHZ-4GB-RAM-320GB-12-5/264843886803?hash=item3da9ed00d3%3Ag%3A5vkAAOSwpNxayggC&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '699.89',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Style': 'laptop',
#   'System operating': 'windows 10',
#   'Article modified': "doesn't",
#   'Product non-national': "doesn't",
#   'Size screen': '12,5"',
#   'Gpu': 'intel hd graphics 630',
#   'Type unity': 'unity',
#   'Model': 'i5-3320m',
#   'Capacity disk hard': '500 gb',
#   'Processor': 'intel celeron m',
#   'Brand': 'lenovo',
#   'Type storage': 'hdd (unity disk hard)',
#   'Memory ram': '4 gb',
#   'Capacity ssd': '320gb',
#   'Amount of units': '1',
#   'Features': 'bluetooth',
#   'Year launch': '2016',
#   'Color': 'black',
#   'Screen size': 'does not apply',
#   'Mpn': 'x230',
#   'Resolution maximum': '1280 x 720',
#   'Type card graphic': 'integrated',
#   'Speed of the processor': '2,6 ghz',
#   'Edition of the system operating': 'professional',
#   'Manufacturer warranty': '1 year',
#   'Upc': 'does not apply'},
#  '15': {'Title': 'lenovo ideapad l340 15.6" gaming laptop intel core i5-9300h 8gb ram 128gb ssd',
#   'Link': 'https://www.ebay.com.sg/itm/Lenovo-IdeaPad-L340-15-6-Gaming-Laptop-Intel-Core-i5-9300H-8GB-RAM-128GB-SSD/293979820225?hash=item44729010c1%3Ag%3AreEAAOSw5d5fhL81&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '1166.8',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Release year': '2019',
#   'Hardware connectivity': 'usb 3.0',
#   'Screen size': '15.6 in',
#   'Maximum resolution': '1920 x 1080',
#   'Graphics processing type': 'integrated/on-board graphics',
#   'Operating system': 'windows 10',
#   'Features': 'backlit keyboard, bluetooth, built-in webcam, built-in microphone, multi-touch trackpad',
#   'Model': 'lenovo ideapad l340',
#   'Color': 'black',
#   'Ram size': '8 gb',
#   'Series': 'ideapad',
#   'Type': 'notebook/laptop',
#   'Brand': 'lenovo',
#   'Manufacturer colour': 'black',
#   'Ssd capacity': '128 gb',
#   'Storage type': 'ssd (solid state drive)',
#   'Processor': 'intel core i5 9th gen.',
#   'Upc': 'does not apply'},
#  '16': {'Title': 'hp pavilion 14-ce3600sa 14" full hd intel core i3-1005g1 8gb 256gb ssd laptop',
#   'Link': 'https://www.ebay.com.sg/itm/HP-Pavilion-14-ce3600sa-14-Full-HD-Intel-Core-i3-1005G1-8GB-256GB-SSD-Laptop/303873278616?hash=item46c0424298%3Ag%3AelgAAOSwleBf5IJ5&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '746.18',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Screen size': '14 in',
#   'Maximum resolution': '1920 x 1080',
#   'Operating system': 'windows 10 (64-bit)',
#   'Most suitable for': 'casual computing',
#   'Features': 'built-in microphone, built-in webcam, bluetooth, multi-touch trackpad',
#   'Model': 'hp pavilion 14-ce3600sa',
#   'Color': 'mineral silver',
#   'Ram size': '8 gb',
#   'Series': 'pavilion',
#   'Type': 'notebook/laptop',
#   'Brand': 'hp',
#   'Processor': 'intel core i3 10th gen.',
#   'Ssd capacity': '256 gb',
#   'Storage type': 'ssd (solid state drive)',
#   'Connectivity': 'usb 1.0/1.1, usb 3.0, usb 3.1, hdmi',
#   'Upc': 'does not apply'},
#  '17': {'Title': 'laptop computer hp 8570p i5 10531 6/12ft 8gb 120gb ssd 15,6 w10 (propuestas)',
#   'Link': 'https://www.ebay.com.sg/itm/Laptop-Computer-HP-8570P-I5-10531-6-12ft-8GB-120GB-SSD-15-6-W10-Propuestas/264897133090?hash=item3dad197a22%3Ag%3AeggAAOSw6Jxa%7EWzH&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '816.55',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Style': 'laptop',
#   'System operating': 'windows 10',
#   'Memory ram': '8 gb',
#   'Gpu': 'intel hd',
#   'Size screen': '15,6"',
#   'Model': 'i5-3210m',
#   'Type unity': 'unity',
#   'Processor': 'i5 3210m',
#   'Capacity disk hard': '120gb',
#   'Type storage': 'hdd (unity disk hard)',
#   'Brand': 'hp',
#   'Capacity ssd': '120 gb',
#   'Amount of units': '1',
#   'Features': '10/100 card lan, robust',
#   'Size of ram': '8 gb',
#   'Color': 'black-grey',
#   'Year launch': '2017',
#   'Mpn': '8570p',
#   'Screen size': 'does not apply',
#   'Type card graphic': 'integrated',
#   'Resolution maximum': '1360 x 768',
#   'Edition of the system operating': 'professional',
#   'Speed of the processor': '2,50 ghz',
#   'Upc': 'does not apply',
#   'Manufacturer warranty': '1 year'},
#  '18': {'Title': 'lenovo ideapad 5i 14iil05 14" full hd laptop intel i5-1035g1 8gb ram 256gb ssd',
#   'Link': 'https://www.ebay.com.sg/itm/LENOVO-IDEAPAD-5i-14IIL05-14-FULL-HD-LAPTOP-INTEL-i5-1035G1-8GB-RAM-256GB-SSD/114669169464?hash=item1ab2d0ab38%3Ag%3AlBIAAOSwhYVgHd68&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '926.03',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Screen size': '14 in',
#   'Hard drive capacity': '256 gb',
#   'Operating system': 'windows 10',
#   'Model': 'ideapad 5-14iil05',
#   'Features': 'built-in microphone, built-in webcam, bluetooth, multi-touch trackpad',
#   'Ram size': '8 gb',
#   'Color': 'blue',
#   'Type': 'notebook/laptop',
#   'Series': 'ideapad',
#   'Processor': 'intel core i5 10th gen.',
#   'Brand': 'lenovo',
#   'Storage type': 'ssd (solid state drive)',
#   'Ssd capacity': '256 gb',
#   'Upc': 'does not apply',
#   'Maximum resolution': '1920 x 1080'},
#  '19': {'Title': 'asus c302ca laptop google chromebook lightweight m3 64gb 12" full hd touchscreen',
#   'Link': 'https://www.ebay.com.sg/itm/Asus-C302CA-Laptop-Google-Chromebook-Lightweight-M3-64GB-12-Full-HD-Touchscreen/274654207330?hash=item3ff2aa9d62%3Ag%3AtHwAAOSwHsxgCFyL&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '539.19',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Ram size': '4 gb',
#   'Connectivity': 'usb-c, usb 3.0',
#   'Graphics processing type': 'integrated/on-board graphics',
#   'Hard drive capacity': '64 gb',
#   'Features': 'touchscreen, wi-fi, built-in webcam, bluetooth',
#   'Color': 'silver',
#   'Modified item': 'no',
#   'Operating system': 'chrome os',
#   'Mpn': 'does not apply',
#   'Model': 'c302ca-gu010',
#   'Screen size': '12.5 in full hd',
#   'Type': 'notebook/laptop',
#   'Brand': 'asus',
#   'Processor speed': '0.90 ghz',
#   'Non-domestic product': 'no',
#   'Storage type': 'emmc',
#   'Custom bundle': 'no',
#   'Upc': 'does not apply',
#   'Processor': 'intel m3-6y30'},
#  '20': {'Title': 'aftershock apex 15 gaming laptop i7-8750h gtx 1060 with warranty (sg)',
#   'Link': 'https://www.ebay.com.sg/itm/Aftershock-Apex-15-Gaming-Laptop-i7-8750h-gtx-1060-with-warranty-SG/143793574426?hash=item217ac3d21a%3Ag%3AFuYAAOSw4slfjCRl&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '1350.0',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Type': 'notebook/laptop',
#   'Screen size': '15.6 in',
#   'Brand': 'aftershock',
#   'Gpu': 'gtx 1060',
#   'Operating system': 'windows 10',
#   'Storage type': 'ssd (solid state drive)',
#   'Model': 'apex 15',
#   'Ssd capacity': '512 gb',
#   'Maximum resolution': '1920 x 1080',
#   'Processor': 'intel core i7 8th gen.',
#   'Release year': '2018'},
#  '21': {'Title': 'msi gf75 thin 17.3” gaming laptop hexa core intel core i7 gtx 1660ti 512 gb ssd',
#   'Link': 'https://www.ebay.com.sg/itm/MSI-GF75-Thin-17-3-Gaming-Laptop-Hexa-Core-Intel-Core-i7-GTX-1660Ti-512-GB-SSD/303863184534?hash=item46bfa83c96%3Ag%3AB5QAAOSwADZfh30E&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '1815.04',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Speakers': 'dual 2 w speakers',
#   'Screen size': '17.3 in',
#   'Usb': '- usb type-c x 1 ;- usb 3.1 x 3',
#   'Screen type': 'ips lcd',
#   'Storage': '512 gb ssd',
#   'Weight grams': '2250',
#   'Width (mm)': '396.1',
#   'Battery type': '4-cell lithium-ion',
#   'Maximum resolution': '1920 x 1080',
#   'Model': 'gf75 thin',
#   'Gpu': '1660ti',
#   'Processor': 'intel core i7 10th gen.',
#   'Ram size': '8 gb',
#   'Height (mm)': '18.9',
#   'Type': 'notebook/laptop',
#   'Item height': '18.9',
#   'Processor speed': '4.70 ghz',
#   'Ethernet': 'killer e2500 ethernet port',
#   'Dimensions': '18.9 x 396.1 x 259.4 mm (h x w x d)',
#   'Color': 'black',
#   'Touchscreen': 'no',
#   'Depth (mm)': '259.4',
#   'Operating system': 'windows 10',
#   'Bluetooth': 'bluetooth 5.0',
#   'Storage type': 'ssd (solid state drive)',
#   'Mpn': '9s717f312080',
#   'Brand': 'msi',
#   'Hard drive capacity': '512 gb',
#   'Wifi': '- wifi 6 ;- 2x2 ;- up to 1.73 gbps',
#   'Features': 'built-in microphone, backlit keyboard, built-in webcam, bluetooth, multi-touch trackpad',
#   'Ssd capacity': '512 gb',
#   'Upc': 'does not apply',
#   'Connectivity': 'usb 3.1',
#   'Ean': '4719072735692',
#   'Audio connections': '3.5 mm jack'},
#  '22': {'Title': 'laptop black fusitsu siemens lifebook s2110 fsc 1gb 2.1oz windows xp ati radeon',
#   'Link': 'https://www.ebay.com.sg/itm/Laptop-Black-Fusitsu-Siemens-Lifebook-S2110-FSC-1GB-2-1oz-Windows-XP-Ati-Radeon/224250390833?hash=item34365d6931%3Ag%3AZTgAAOSwv4tdL2tI&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '253.2',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Model': 's2110',
#   'Graphic processor': 'integrated graphic',
#   'Operating system': 'windows xp',
#   'Hard drive capacity': '60gb',
#   'Memory ram': '1gb',
#   'Product line': 'lifebook',
#   'Mpn': 'not applicable',
#   'Ssd hard drive capacity': 'not applicable',
#   'Screen size': '13,3 zoll (33,8 cm)',
#   'Processor speed': '2ghz',
#   'Hard drive type': 'hdd (hard disk drive)',
#   'Type': 'notebook/laptop',
#   'Ean': '7427055324241',
#   'Brand': 'fujitsu siemens',
#   'Processor': 'does not apply',
#   'Upc': 'does not apply'},
#  '23': {'Title': 'hp 14s-dq1505sa 14" ips wled full hd laptop intel quad core i7 8gb ram 512gb ssd',
#   'Link': 'https://www.ebay.com.sg/itm/HP-14s-dq1505sa-14-IPS-WLED-Full-HD-Laptop-Intel-Quad-Core-i7-8GB-RAM-512GB-SSD/293993396544?hash=item44735f3940%3Ag%3AUbkAAOSw-11fwZAe&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '1000.08',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Item width': '22.5 cm',
#   'Item weight': '1.46 kg',
#   'Maximum resolution': '1920 x 1080',
#   'Processor speed': '1.30 ghz',
#   'Ram size': '8 gb',
#   'Processor': 'intel core i7 10th gen.',
#   'Type': 'notebook/laptop',
#   'Item height': '1.79 cm',
#   'Model': 'hp 14s-dq1505sa',
#   'Graphics processing type': 'integrated/on-board graphics',
#   'Operating system': 'windows 10',
#   'Features': 'bluetooth, built-in webcam, built-in microphone, wi-fi, multi-touch trackpad',
#   'Storage type': 'ssd (solid state drive)',
#   'Mpn': '9mn84eaabu',
#   'Brand': 'hp',
#   'Color': 'silver',
#   'Ssd capacity': '512 gb',
#   'Hard drive capacity': '512 gb',
#   'Connectivity': 'usb-c, usb 3.1',
#   'Most suitable for': 'graphic design, workstation, casual computing, light gaming',
#   'Item length': '32.4 cm',
#   'Release year': '2020',
#   'Manufacturer colour': 'natural silver',
#   'Upc': 'does not apply',
#   'Screen size': '14 in',
#   'Ean': '0194850069604'},
#  '24': {'Title': 'dell latitude 14 7414 rugged extreme laptop i7-6600u 32gb 2tb ssd a-gps 4g lte',
#   'Link': 'https://www.ebay.com.sg/itm/Dell-Latitude-14-7414-Rugged-Extreme-Laptop-i7-6600U-32GB-2TB-SSD-A-GPS-4G-LTE/164210606551?hash=item263bb701d7%3Ag%3AiKoAAOSw0qFdabKE&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '3187.91',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Modified item': 'no',
#   'Screen size': '14in.',
#   'Custom bundle': 'no',
#   'Product line': 'latitude',
#   'Memory': '32gb',
#   'Model': '7414',
#   'Operating system edition': 'professional',
#   'Processor': 'does not apply',
#   'Type': 'notebook/laptop',
#   'Features': 'touchscreen, mobile broadband [4g lte], bluetooth, a-gps, triple rf - passthough, backlit keyboard',
#   'Processor speed': '2.30ghz',
#   'Mpn': '7414',
#   'Operating system': 'windows 10',
#   'Non-domestic product': 'no',
#   'Storage type': 'ssd (solid state drive)',
#   'Processor type': 'intel core i7 6th gen.',
#   'Brand': 'dell',
#   'Optical drive': 'none',
#   'Ssd capacity': '2tb',
#   'Release year': '2016',
#   'Hardware connectivity': 'displayport',
#   'Upc': 'does not apply'},
#  '25': {'Title': 'lenovo ideapad 530s-14arr 14" full hd amd ryzen 7 2700 laptop 8gb ram 256 gb ssd',
#   'Link': 'https://www.ebay.com.sg/itm/LENOVO-Ideapad-530s-14ARR-14-Full-HD-AMD-Ryzen-7-2700-Laptop-8GB-RAM-256-GB-SSD/303864474062?hash=item46bfbbe9ce%3Ag%3AnscAAOSwkPlgGyJ7&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '888.99',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Mpn': '81h1001duk',
#   'Most suitable for': 'casual computing',
#   'Graphics processing type': 'integrated/on-board graphics',
#   'Operating system': 'windows 10',
#   'Features': 'bluetooth, built-in webcam, built-in microphone, backlit keyboard',
#   'Manufacturer colour': 'black',
#   'Color': 'black',
#   'Hard drive capacity': '256 gb',
#   'Type': 'notebook/laptop',
#   'Model': 'lenovo ideapad 530s',
#   'Brand': 'lenovo',
#   'Ram size': '8 gb',
#   'Processor speed': '3.60 ghz',
#   'Screen size': '14 in',
#   'Ssd capacity': '256 gb',
#   'Release year': '2018',
#   'Processor': 'amd ryzen 7',
#   'Storage type': 'ssd (solid state drive)',
#   'Connectivity': 'usb-c, usb 3.0, hdmi, sd card slot',
#   'Upc': 'does not apply',
#   'Maximum resolution': '1920 x 1080'},
#  '26': {'Title': 'apple macbook pro 15" 2014 retina a1398 laptop i7-4870hq 256gb 16gb big sur',
#   'Link': 'https://www.ebay.com.sg/itm/Apple-MacBook-Pro-15-2014-Retina-A1398-Laptop-i7-4870HQ-256GB-16GB-Big-Sur/303806780108?hash=item46bc4b92cc%3Ag%3AGbgAAOSwVs1f01r8&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '1212.54',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Model': 'a1398',
#   'Most suitable for': 'casual computing',
#   'Type': 'notebook/laptop',
#   'Gpu': 'nvidia geforce gt 750m',
#   'Features': 'wi-fi',
#   'Processor speed': '2.50 ghz',
#   'Mpn': 'mgxc2ll/a',
#   'Ram size': '16 gb',
#   'Series': 'macbook pro',
#   'Screen size': '15.4 in',
#   'Brand': 'apple',
#   'Processor': 'intel core i7 4th gen.',
#   'Storage capacity': '256gb',
#   'Storage type': 'ssd (solid state drive)',
#   'Ssd capacity': '256 gb',
#   'Upc': 'does not apply',
#   'Connectivity': 'hdmi'},
#  '27': {'Title': 'asus zenbook ux305fa 13.3" full hd m-5y10 8gb 256gb lightweight laptop ultrabook',
#   'Link': 'https://www.ebay.com.sg/itm/ASUS-ZenBook-UX305FA-13-3-Full-HD-M-5Y10-8GB-256GB-Lightweight-Laptop-Ultrabook/274652037819?hash=item3ff28982bb%3Ag%3AHHkAAOSwE7lfduyD&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '839.44',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Processor': 'intel core m',
#   'Type': 'notebook/laptop',
#   'Release year': '2015',
#   'Color': 'black',
#   'Operating system': 'windows 10',
#   'Graphics processing type': 'integrated/on-board graphics',
#   'Features': 'wi-fi',
#   'Model': 'ux305fa-fc061h',
#   'Mpn': 'ux305fafc061h',
#   'Ram size': '8 gb',
#   'Series': 'zenbook',
#   'Screen size': '13.3 in',
#   'Brand': 'asus',
#   'Processor speed': '800 mhz',
#   'Compatible model': 'asus',
#   'Storage type': 'ssd (solid state drive)',
#   'Ssd capacity': '256 gb',
#   'Upc': 'does not apply',
#   'Connectivity': 'usb 3.0'},
#  '28': {'Title': 'notebook laptop siemens simatic filed pg m 6es7712-1bb10-0af0 programming device',
#   'Link': 'https://www.ebay.com.sg/itm/Notebook-Laptop-SIEMENS-Simatic-Filed-Pg-M-6ES7712-1BB10-0AF0-Programming-Device/224250390174?hash=item34365d669e%3Ag%3ANfEAAOSwkNRd3B9l&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '1578.94',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Operating system': 'windows xp',
#   'Hard drive capacity': '80gb',
#   'Memory ram': '128mb',
#   'Ssd hard drive capacity': 'not applicable',
#   'Mpn': '6es7712-1bb10-0af0',
#   'Product line': 'simatic',
#   'Screen size': '15 zoll (38,5 cm)',
#   'Model': 'filed pg m',
#   'Hard drive type': 'hdd (hard disk drive)',
#   'Type': 'netbook/notebook/laptop',
#   'Ean': '7427055325316',
#   'Brand': 'siemens',
#   'Processor speed': '2ghz',
#   'Processor type': 'intel pentium iii',
#   'Processor': 'does not apply',
#   'Upc': 'does not apply',
#   'Graphic processor': 'integrated graphic'},
#  '29': {'Title': 'asus tp410u 14 inch fhd laptop 8th gen i5-8250u 8gb ram 256gb ssd windows 10',
#   'Link': 'https://www.ebay.com.sg/itm/ASUS-TP410U-14-inch-FHD-Laptop-8th-Gen-i5-8250U-8GB-RAM-256GB-SSD-Windows-10/193074701723?hash=item2cf426259b%3Ag%3AuY4AAOSw8VhdZ%7E%7Eh&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '899.0',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Brand': 'asus',
#   'Color': 'gray',
#   'Mpn': 'x441ba-cba6a',
#   'Model': 'asus vivobook',
#   'Operating system': 'windows 10',
#   'Type': 'notebook/laptop',
#   'Screen size': '14in',
#   'Most suitable for': 'working, studying',
#   'Processor': '7th generation amd a6-9225',
#   'Operating system edition': 'home',
#   'Processor speed': '2.60ghz',
#   'Modified item': 'no',
#   'Storage type': 'ssd (solid state drive)',
#   'Ram size': '8 gb',
#   'Release year': '2018',
#   'Ssd capacity': '256gb'},
#  '30': {'Title': 'laptop computer lenovo x240 i5 14107 7/12ft 2,6ghz 4gb ram 128gb ssd 12,5 (',
#   'Link': 'https://www.ebay.com.sg/itm/Laptop-Computer-Lenovo-X240-I5-14107-7-12ft-2-6GHZ-4GB-RAM-128GB-SSD-12-5/264842884619?hash=item3da9ddb60b%3Ag%3ApSsAAOSwIzBaygj%7E&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '863.21',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Style': 'laptop',
#   'System operating': 'windows 10',
#   'Memory ram': '4 gb',
#   'Gpu': 'intel hd graphics 630',
#   'Size screen': '12,5"',
#   'Model': 'i5-4300m',
#   'Type unity': 'unity',
#   'Processor': 'intel celeron m',
#   'Capacity disk hard': '128gb',
#   'Type storage': 'hdd (unity disk hard)',
#   'Brand': 'lenovo',
#   'Capacity ssd': '128 gb',
#   'Amount of units': '1',
#   'Features': 'microphone built-in',
#   'Size of ram': '4 gb',
#   'Color': 'black',
#   'Year launch': '2016',
#   'Mpn': 'x240',
#   'Screen size': 'does not apply',
#   'Type card graphic': 'integrated',
#   'Resolution maximum': '1280 x 768',
#   'Edition of the system operating': 'professional',
#   'Speed of the processor': '2,6 ghz',
#   'Upc': 'does not apply',
#   'Manufacturer warranty': '1 year'},
#  '31': {'Title': 'retro notebook compaq armada 4150 pentium 150mhz mmx laptop windows 95 98 cdrom',
#   'Link': 'https://www.ebay.com.sg/itm/Retro-Notebook-Compaq-Armada-4150-Pentium-150MHZ-Mmx-Laptop-Windows-95-98-Cdrom/324390977254?hash=item4b87357ee6%3Ag%3AurIAAOSwCLxdLbFf&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '614.65',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Operating system': 'windows 98',
#   'Graphic processor': 'integrated graphic',
#   'Memory ram': '32mb',
#   'Hard drive capacity': '5gb',
#   'Mpn': 'not applicable',
#   'Product line': 'aramada',
#   'Screen size': '12,1 zoll (30,7 cm)',
#   'Ssd hard drive capacity': 'not applicable',
#   'Hard drive type': 'hdd (hard disk drive)',
#   'Model': '4150',
#   'Ean': '7427055324227',
#   'Type': 'notebook/laptop',
#   'Processor speed': '150mhz',
#   'Brand': 'compaq',
#   'Processor type': 'intel pentium mmx',
#   'Upc': 'does not apply',
#   'Processor': 'does not apply'},
#  '32': {'Title': 'hp pavilion 15-cw1598sa 15.6" touchscreen laptop amd ryzen 7 16gb ram 512gb ssd',
#   'Link': 'https://www.ebay.com.sg/itm/HP-Pavilion-15-CW1598SA-15-6-Touchscreen-Laptop-AMD-Ryzen-7-16GB-RAM-512GB-SSD/114667103670?hash=item1ab2b125b6%3Ag%3AsfYAAOSwwQ1gBhvR&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '1279.16',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Hard drive capacity': '512 gb',
#   'Maximum resolution': '1920 x 1080',
#   'Screen size': '15.6 in',
#   'Most suitable for': 'casual computing',
#   'Graphics processing type': 'integrated/on-board graphics',
#   'Gpu': 'amd radeon rx vega 10 graphics',
#   'Features': 'touchscreen, built-in microphone, built-in webcam, bluetooth, multi-touch trackpad',
#   'Operating system': 'windows 10 home',
#   'Mpn': '6td28ea',
#   'Model': '15-cw1598sa',
#   'Series': 'pavilion',
#   'Ram size': '16 gb',
#   'Brand': 'hp',
#   'Type': 'notebook/laptop',
#   'Ssd capacity': '512 gb',
#   'Processor speed': '2.3 ghz',
#   'Processor': 'amd ryzen 7',
#   'Storage type': 'ssd (solid state drive)',
#   'Color': 'silver',
#   'Upc': 'does not apply'},
#  '33': {'Title': 'acer acernote light 370pcx case motherboard laptop ok',
#   'Link': 'https://www.ebay.com.sg/itm/Acer-Acernote-Light-370PCX-Case-Motherboard-Laptop-Ok/224250390490?hash=item34365d67da%3Ag%3AhFwAAOSwlwldTGem&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '110.0',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Model': '370pcx',
#   'Ssd hard drive capacity': 'not applicable',
#   'Memory ram': '512mb',
#   'Product line': 'acernote light',
#   'Mpn': 'not applicable',
#   'Processor type': 'intel celeron m',
#   'Type': 'notebook/laptop case / mainoard',
#   'Screen size': 'does not apply',
#   'Brand': 'acer',
#   'Processor': 'does not apply',
#   'Ean': '7427055324548',
#   'Upc': 'does not apply',
#   'Graphic processor': 'integrated graphic'},
#  '34': {'Title': 'hp 255 g7 15.6" full hd laptop quad core amd ryzen 5 3500u 8gb ram 256 gb ssd',
#   'Link': 'https://www.ebay.com.sg/itm/HP-255-G7-15-6-Full-HD-Laptop-Quad-Core-AMD-Ryzen-5-3500u-8GB-RAM-256-GB-SSD/114667103683?hash=item1ab2b125c3%3Ag%3AiRAAAOSwS4df2qW7&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '888.99',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Operating system': 'windows 10',
#   'Model': 'hp 255 g7',
#   'Features': 'built-in microphone, built-in webcam, bluetooth, multi-touch trackpad',
#   'Ram size': '8 gb',
#   'Color': 'black',
#   'Type': 'notebook/laptop',
#   'Screen size': '15.6 in',
#   'Processor': 'amd ryzen 5',
#   'Brand': 'hp',
#   'Storage type': 'ssd (solid state drive)',
#   'Ssd capacity': '256 gb',
#   'Upc': 'does not apply',
#   'Maximum resolution': '1920 x 1080'},
#  '35': {'Title': 'acer aspire 3 a315-56 15.6" hd intel quad core i5-1035g1 8gb 1tb hdd laptop red',
#   'Link': 'https://www.ebay.com.sg/itm/Acer-Aspire-3-A315-56-15-6-HD-Intel-Quad-Core-i5-1035G1-8GB-1TB-HDD-Laptop-Red/303863184517?hash=item46bfa83c85%3Ag%3AMLAAAOSwhIRgEfgN&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '839.46',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Operating system': 'windows 10',
#   'Hard drive capacity': '1 tb',
#   'Features': 'built-in microphone, built-in webcam, bluetooth, multi-touch trackpad',
#   'Release year': '2020',
#   'Color': 'red',
#   'Ram size': '8 gb',
#   'Screen size': '15.6 in',
#   'Type': 'notebook/laptop',
#   'Brand': 'acer',
#   'Model': 'acer aspire 3',
#   'Ssd capacity': '1 tb',
#   'Storage type': 'hdd (hard disk drive)',
#   'Processor': 'intel core i5 10th gen.',
#   'Upc': 'does not apply',
#   'Maximum resolution': '1366 x 768'},
#  '36': {'Title': 'dell inspiron 15 5567 gaming laptop 15.6" full hd 2tb 16gb i7-7500u dvd black',
#   'Link': 'https://www.ebay.com.sg/itm/Dell-Inspiron-15-5567-Gaming-Laptop-15-6-Full-HD-2TB-16GB-i7-7500U-DVD-Black/303897084401?hash=item46c1ad81f1%3Ag%3Atz0AAOSwQpZgNSdh&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '1208.57',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Modified item': 'no',
#   'Processor speed': '2.70 ghz',
#   'Custom bundle': 'no',
#   'Processor': 'intel core i7 7th gen.',
#   'Maximum resolution': '1920 x 1080',
#   'Graphics processing type': 'dedicated graphics',
#   'Ram size': '16 gb',
#   'Features': 'dvdrw drive, wi-fi, built-in webcam, bluetooth',
#   'Type': 'notebook/laptop',
#   'Mpn': 'does not apply',
#   'Operating system': 'windows 10',
#   'Series': 'inspiron',
#   'Storage type': 'hdd (hard disk drive)',
#   'Non-domestic product': 'no',
#   'Brand': 'dell',
#   'Color': 'black',
#   'Connectivity': 'usb 2.0, usb 3.0, hdmi',
#   'Hard drive capacity': '2 tb',
#   'Screen size': '15.6 in full hd',
#   'Most suitable for': 'graphic design, serious gaming, casual computing, light gaming',
#   'Gpu': 'amd radeon r7 m445',
#   'Upc': 'does not apply'},
#  '37': {'Title': 'lenovo ideapad 3i 14" full hd laptop quad core intel i7-1065g7 8gb ram 256gb ssd',
#   'Link': 'https://www.ebay.com.sg/itm/LENOVO-IDEAPAD-3i-14-Full-HD-Laptop-Quad-Core-Intel-i7-1065G7-8GB-RAM-256GB-SSD/303864474249?hash=item46bfbbea89%3Ag%3Az%7EQAAOSw2VtgHdxF&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '981.59',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Screen size': '14 in',
#   'Hard drive capacity': '256 gb',
#   'Operating system': 'windows 10',
#   'Model': 'ideapad 3-14iil05',
#   'Features': 'built-in microphone, built-in webcam, bluetooth, multi-touch trackpad',
#   'Ram size': '8 gb',
#   'Color': 'blue',
#   'Type': 'notebook/laptop',
#   'Series': 'ideapad',
#   'Processor': 'intel core i7 10th gen.',
#   'Brand': 'lenovo',
#   'Storage type': 'ssd (solid state drive)',
#   'Ssd capacity': '256 gb',
#   'Upc': 'does not apply',
#   'Maximum resolution': '1920 x 1080'},
#  '38': {'Title': 'asus zenbook ux360ca 13.3" full hd touchscreen m5-6y54 256gb lightweight laptop',
#   'Link': 'https://www.ebay.com.sg/itm/ASUS-ZenBook-UX360CA-13-3-Full-HD-Touchscreen-M5-6Y54-256GB-Lightweight-Laptop/274615297268?hash=item3ff058e4f4%3Ag%3AHHkAAOSwE7lfduyD&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '839.44',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Release year': '2015',
#   'Connectivity': 'usb 3.0, micro-hdmi',
#   'Operating system': 'windows 10',
#   'Type': 'notebook/laptop',
#   'Features': 'touchscreen, wi-fi, built-in webcam',
#   'Color': 'gold',
#   'Mpn': 'ux305fafc061h',
#   'Model': 'asus zenbook',
#   'Series': 'zenbook',
#   'Ram size': '8 gb',
#   'Brand': 'asus',
#   'Screen size': '13.3 in full hd',
#   'Graphics processing type': 'integrated/on-board graphics',
#   'Processor speed': '1.10 ghz',
#   'Compatible model': 'asus',
#   'Storage type': 'ssd (solid state drive)',
#   'Ssd capacity': '256 gb',
#   'Upc': 'does not apply',
#   'Processor': 'intel core m',
#   'Ean': '4716659996408'},
#  '39': {'Title': '3 days delivery [refurbished] lenovo thinkpad t430 core i5-2520m business laptop',
#   'Link': 'https://www.ebay.com.sg/itm/3-Days-Delivery-Refurbished-LENOVO-THINKPAD-T430-Core-i5-2520M-Business-Laptop/373111844534?hash=item56df32eeb6%3Ag%3Ate0AAOSwUQFfAHVP&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '235.0',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Brand': 'lenovo',
#   'Hard drive capacity': '320 gb',
#   'Operating system': 'windows 10',
#   'Processor speed': '2.50 ghz',
#   'Model': 'lenovo thinkpad t430',
#   'Most suitable for': 'casual computing, light gaming, workstation',
#   'Type': 'notebook/laptop',
#   'Series': 'thinkpad',
#   'Release year': '2012',
#   'Screen size': '14 in',
#   'Country/region of manufacture': 'china',
#   'Item weight': '2.2',
#   'Ram size': '4 gb',
#   'Storage type': 'hdd (hard disk drive)',
#   'Connectivity': 'mini displayport, hdmi, usb 2.0, usb 3.0, gigabit ethernet, vga, sd card slot',
#   'Gpu': 'intel hd graphics 4000',
#   'Color': 'black',
#   'Manufacturer warranty': '1 month',
#   'Features': 'bluetooth, built-in microphone, built-in webcam, wi-fi',
#   'Processor': 'intel core i5 2nd gen.'},
#  '40': {'Title': 'dell xps 15 7590 fast full hd led ultrabook laptop 512gb ssd 16gb i7-9750h',
#   'Link': 'https://www.ebay.com.sg/itm/Dell-XPS-15-7590-Fast-Full-HD-LED-Ultrabook-Laptop-512GB-SSD-16GB-i7-9750H/274457335726?hash=item3fe6ee97ae%3Ag%3Aa8sAAOSwIlBeZ59N&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '2696.09',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Modified item': 'no',
#   'Gpu': 'nvidia(r) geforce(r) gtx 1650 4gb gddr5',
#   'Custom bundle': 'no',
#   'Processor speed': '2.60 ghz 6 cores',
#   'Ram size': '16 gb',
#   'Processor': 'intel core i7-9750h 9th gen hexa 6 core',
#   'Type': 'notebook/laptop',
#   'Graphics processing type': 'dedicated graphics nvidia(r) geforce(r) gtx 1650',
#   'Model': 'dell xps 15 7590',
#   'Features': 'backlit keyboard, built-in webcam, bluetooth',
#   'Operating system': 'windows 10',
#   'Color': 'silver',
#   'Storage type': 'ssd (solid state drive)',
#   'Non-domestic product': 'no',
#   'Brand': 'dell',
#   'Hard drive capacity': 'not applicable',
#   'Ssd capacity': '512 gb',
#   'Release year': '2019',
#   'Connectivity': 'usb 2.0, usb-c, usb 3.0, hdmi',
#   'Upc': 'does not apply',
#   'Screen size': '15.6 in'},
#  '41': {'Title': 'lenovo s340 15.6" full hd laptop intel pentium 5045u 4gb ram 128gb ssd notebook',
#   'Link': 'https://www.ebay.com.sg/itm/Lenovo-S340-15-6-Full-HD-Laptop-Intel-Pentium-5045U-4GB-RAM-128GB-SSD-Notebook/114654164950?hash=item1ab1ebb7d6%3Ag%3AogwAAOSw8Wlf2-W9&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '545.98',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Operating system': 'windows 10 s',
#   'Hard drive capacity': '128 gb',
#   'Features': 'built-in microphone, built-in webcam, bluetooth, multi-touch trackpad',
#   'Model': 'lenovo s340',
#   'Color': 'silver',
#   'Ram size': '4 gb',
#   'Screen size': '15.6 in',
#   'Type': 'notebook/laptop',
#   'Brand': 'lenovo',
#   'Release year': '2020',
#   'Ssd capacity': '128 gb',
#   'Storage type': 'ssd (solid state drive)',
#   'Processor': 'intel pentium',
#   'Upc': 'does not apply',
#   'Maximum resolution': '1920 x 1080'},
#  '42': {'Title': 'panasonic toughbook cf-c2 i5-4th gen 4-12gb 128gb-960g touch rugged laptop-b',
#   'Link': 'https://www.ebay.com.sg/itm/Panasonic-Toughbook-CF-C2-i5-4TH-GEN-4-12GB-128GB-960G-Touch-Rugged-Laptop-B/303672116353?hash=item46b444c481%3Ag%3Aie0AAOSw-ntfTsrH&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '345.0',
#   'Description': ''},
#  '43': {'Title': 'msi bravo 15 15.6" 120hz gaming laptop ryzen 7 4800h rx 5500m 512gb ssd 8gb ram',
#   'Link': 'https://www.ebay.com.sg/itm/MSI-Bravo-15-15-6-120Hz-Gaming-Laptop-Ryzen-7-4800H-RX-5500M-512GB-SSD-8GB-RAM/114655808525?hash=item1ab204cc0d%3Ag%3AJIgAAOSwD7Nf4RnH&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '1444.62',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Graphics processing type': 'dedicated graphics',
#   'Operating system': 'windows 10',
#   'Features': 'backlit keyboard, bluetooth, built-in webcam, built-in microphone, multi-touch trackpad',
#   'Model': 'msi bravo 15',
#   'Screen size': '15.6 in',
#   'Ram size': '8 gb',
#   'Brand': 'msi',
#   'Type': 'notebook/laptop',
#   'Ssd capacity': '512 gb',
#   'Processor': 'amd ryzen 7',
#   'Hard drive capacity': '256 gb',
#   'Storage type': 'ssd (solid state drive)',
#   'Most suitable for': 'graphic design, workstation, serious gaming, casual computing, light gaming',
#   'Upc': 'does not apply',
#   'Gpu': 'rx 5500m 4gb'},
#  '44': {'Title': 'asus vivobook 14" full hd quad core amd ryzen 7 3700u 8gb ram 1tb ssd laptop',
#   'Link': 'https://www.ebay.com.sg/itm/Asus-VivoBook-14-Full-HD-Quad-Core-AMD-Ryzen-7-3700u-8GB-RAM-1TB-SSD-Laptop/303863184511?hash=item46bfa83c7f%3Ag%3AwBIAAOSwby9gEfWN&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '1074.16',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Operating system': 'windows 10',
#   'Graphics processing type': 'integrated',
#   'Features': 'built-in microphone, built-in webcam, bluetooth, multi-touch trackpad',
#   'Hard drive capacity': 'not included',
#   'Ean': '4718017875875',
#   'Model': 'm413da-ek378t',
#   'Color': 'black',
#   'Ram size': '8gb',
#   'Screen size': '14"',
#   'Type': 'windows laptops',
#   'Brand': 'asus',
#   'Processor': 'amd ryzen 7',
#   'Ssd capacity': '1 tb',
#   'Storage type': 'ssd (solid state drive)',
#   'Maximum resolution': '1920 x 1080',
#   'Upc': 'does not apply'},
#  '45': {'Title': 'acer swift 3 14" full hd laptop intel pentium™ gold 4415u 4gb ram 128 gb ssd',
#   'Link': 'https://www.ebay.com.sg/itm/ACER-Swift-3-14-Full-HD-Laptop-Intel-Pentium-Gold-4415U-4GB-RAM-128-GB-SSD/293979820210?hash=item44729010b2%3Ag%3AEK0AAOSwY1FgHePq&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '611.17',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Type': 'notebook/laptop',
#   'Maximum resolution': '1920 x 1080',
#   'Manufacturer colour': 'silver',
#   'Most suitable for': 'casual computing',
#   'Operating system': 'windows 10',
#   'Color': 'silver',
#   'Features': 'backlit keyboard',
#   'Hard drive capacity': '128 gb',
#   'Mpn': 'nxgxzek012',
#   'Model': 'acer swift 3',
#   'Series': 'swift',
#   'Ram size': '4 gb',
#   'Brand': 'acer',
#   'Screen size': '14 in',
#   'Graphics processing type': 'integrated/on-board graphics',
#   'Processor': 'intel pentium',
#   'Ssd capacity': '128 gb',
#   'Storage type': 'ssd (solid state drive)',
#   'Processor speed': '2.30 ghz',
#   'Upc': 'does not apply',
#   'Connectivity': 'usb 3.0, hdmi',
#   'Ean': '4710180484731'},
#  '46': {'Title': 'dell latitude 5404 rugged extreme laptop i7-4650u16gb 2tb ssd gps 4g lte nvidia',
#   'Link': 'https://www.ebay.com.sg/itm/Dell-Latitude-5404-Rugged-Extreme-Laptop-i7-4650U16GB-2TB-SSD-GPS-4G-LTE-NVIDIA/164691408076?hash=item26585f74cc%3Ag%3AS6AAAOSwYBpeEh7r&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '2006.99',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Memory': '16gb',
#   'Model': '5404',
#   'Operating system edition': 'professional',
#   'Processor': 'intel core i7 4th gen.',
#   'Ram size': '16 gb',
#   'Graphics processing type': 'integrated/on-board graphics',
#   'Type': 'notebook/laptop',
#   'Features': 'touchscreen, rugged, assisted gps (a-gps), bluetooth, 4g lte cellular, backlit keyboard, nvidia geforce gt 720m graphics, triple rf - passthough',
#   'Processor speed': '2.0ghz',
#   'Mpn': '5404',
#   'Operating system': 'windows 10',
#   'Series': 'latitude',
#   'Storage type': 'ssd (solid state drive)',
#   'Processor type': 'intel core i7 4th gen.',
#   'Brand': 'dell',
#   'Hard drive capacity': '2tb',
#   'Ssd capacity': '2 tb',
#   'Product line': 'latitude',
#   'Hardware connectivity': 'displayport',
#   'Release year': '2014',
#   'Screen size': '14in.',
#   'Upc': 'does not apply',
#   'Gpu': 'nvidia geforce gt 720m'},
#  '47': {'Title': 'hp 15s-fq1510sa 15.6" full hd laptop intel quad core i5 8gb ram 256gb ssd white',
#   'Link': 'https://www.ebay.com.sg/itm/HP-15s-fq1510sa-15-6-Full-HD-Laptop-Intel-Quad-Core-i5-8GB-RAM-256GB-SSD-White/293995795164?hash=item447383d2dc%3Ag%3ApfcAAOSwcL1gHeBk&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '888.99',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Operating system': 'windows 10',
#   'Hard drive capacity': '256 gb',
#   'Features': 'built-in microphone, built-in webcam, bluetooth, multi-touch trackpad',
#   'Model': '15s-fq1510na',
#   'Color': 'white',
#   'Ram size': '4 gb',
#   'Screen size': '15.6 in',
#   'Type': 'notebook/laptop',
#   'Brand': 'hp',
#   'Processor': 'intel core i5 10th gen.',
#   'Ssd capacity': '256 gb',
#   'Storage type': 'ssd (solid state drive)',
#   'Maximum resolution': '1920 x 1080',
#   'Upc': 'does not apply'},
#  '48': {'Title': 'notebook laptop siemens simatic filed pg m 6es7712-1bb10-0ag programmer 07',
#   'Link': 'https://www.ebay.com.sg/itm/Notebook-Laptop-SIEMENS-Simatic-Filed-Pg-M-6ES7712-1BB10-0AG-Programmer-07/224250390962?hash=item34365d69b2%3Ag%3A0jUAAOSwtg9d4TbG&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '1428.87',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Operating system': 'windows xp',
#   'Hard drive capacity': '80gb',
#   'Memory ram': '128mb',
#   'Ssd hard drive capacity': 'not applicable',
#   'Mpn': '6es7712-1bb10-0ag0',
#   'Product line': 'simatic',
#   'Screen size': '15 zoll (38,5 cm)',
#   'Model': 'filed pg m',
#   'Hard drive type': 'hdd (hard disk drive)',
#   'Type': 'netbook/notebook/laptop',
#   'Ean': '7427055325316',
#   'Brand': 'siemens',
#   'Processor speed': '2ghz',
#   'Processor type': 'intel pentium iii',
#   'Processor': 'does not apply',
#   'Upc': 'does not apply',
#   'Graphic processor': 'integrated graphic'},
#  '49': {'Title': 'asus zenbook pro 15 ux580gd-e2046t i9-8950hk 16gb 512gb 4k touchscreen laptop',
#   'Link': 'https://www.ebay.com.sg/itm/ASUS-ZenBook-Pro-15-UX580GD-E2046T-i9-8950HK-16GB-512GB-4K-Touchscreen-Laptop/274508918394?hash=item3fea01ae7a%3Ag%3AhxcAAOSwASRfbbRM&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '2984.76',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Model': 'ux580gd-e2046t',
#   'Ssd capacity': '512 gb',
#   'Graphics processing type': 'dedicated graphics',
#   'Gpu': 'nvidia gtx 1050',
#   'Storage type': 'ssd (solid state drive)',
#   'Operating system': 'windows 10',
#   'Mpn': 'ux580gd-e2046t',
#   'Ram size': '16 gb',
#   'Type': 'notebook/laptop',
#   'Screen size': '15.6 in',
#   'Brand': 'asus',
#   'Processor': 'intel core i9 8th gen.',
#   'Processor speed': '2.90 ghz',
#   'Upc': 'does not apply'},
#  '50': {'Title': 'hp 14-cf2504sa 14" full hd laptop intel quad core i5-10210u 4gb ram 256gb ssd',
#   'Link': 'https://www.ebay.com.sg/itm/HP-14-cf2504sa-14-Full-HD-Laptop-Intel-Quad-Core-i5-10210U-4GB-RAM-256GB-SSD/303873278633?hash=item46c04242a9%3Ag%3AnE0AAOSwJB1f2-pa&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '851.95',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Operating system': 'windows 10',
#   'Maximum resolution': '1920 x 1080',
#   'Features': 'built-in microphone, built-in webcam, bluetooth, multi-touch trackpad',
#   'Model': '14-cf2504sa',
#   'Color': 'silver',
#   'Ram size': '4 gb',
#   'Screen size': '14 in',
#   'Type': 'notebook/laptop',
#   'Brand': 'hp',
#   'Release year': '2020',
#   'Ssd capacity': '256 gb',
#   'Storage type': 'ssd (solid state drive)',
#   'Processor': 'intel core i5 10th gen.',
#   'Upc': 'does not apply'},
#  '51': {'Title': 'asus zenbook ux305ca ultrabook 13.3" full hd m3-6y30 128gb lightweight laptop',
#   'Link': 'https://www.ebay.com.sg/itm/ASUS-Zenbook-UX305CA-Ultrabook-13-3-Full-HD-M3-6Y30-128GB-Lightweight-Laptop/353212556490?hash=item523d1be4ca%3Ag%3AfiQAAOSwXmRfav0m&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '545.72',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Graphics processing type': 'integrated/on-board graphics',
#   'Hard drive capacity': 'not applicable',
#   'Features': 'backlit keyboard, built-in webcam, bluetooth',
#   'Most suitable for': 'casual computing',
#   'Modified item': 'no',
#   'Ssd capacity': '128 gb',
#   'Color': 'gray',
#   'Operating system': 'windows 10',
#   'Screen size': '13.3 in full hd',
#   'Processor speed': '900mhz to 2.2ghz with turbo boost',
#   'Brand': 'asus',
#   'Ram size': '8 gb',
#   'Non-domestic product': 'no',
#   'Type': 'notebook/laptop',
#   'Custom bundle': 'no',
#   'Model': 'asus zenbook',
#   'Processor': 'intel core m3-6y30',
#   'Storage type': 'ssd (solid state drive)',
#   'Connectivity': 'usb 2.0, usb 3.0, micro-hdmi',
#   'Upc': 'does not apply'},
#  '52': {'Title': 'hp 14-dk0011na 14" full hd quad core amd ryzen 5 3500u 8gb ram 256gb ssd laptop2',
#   'Link': 'https://www.ebay.com.sg/itm/HP-14-dk0011na-14-Full-HD-Quad-Core-AMD-Ryzen-5-3500u-8GB-RAM-256GB-SSD-Laptop2/293993396439?hash=item44735f38d7%3Ag%3AxwoAAOSwzHxf3TiW&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '785.76',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Mpn': '6bl23eaabu',
#   'Most suitable for': 'casual computing',
#   'Graphics processing type': 'integrated/on-board graphics',
#   'Manufacturer colour': 'natural silver',
#   'Features': 'built-in microphone, built-in webcam, bluetooth',
#   'Operating system': 'windows 10',
#   'Color': 'silver',
#   'Model': '14-dk0011na',
#   'Type': 'notebook/laptop',
#   'Ram size': '8 gb',
#   'Brand': 'hp',
#   'Screen size': '14 in',
#   'Processor speed': '2.10 ghz',
#   'Release year': '2019',
#   'Ssd capacity': '256 gb',
#   'Storage type': 'ssd (solid state drive)',
#   'Processor': 'amd ryzen 5',
#   'Upc': 'does not apply',
#   'Connectivity': 'usb-c, usb 3.1, hdmi, sd card slot',
#   'Ean': '0193905467891',
#   'Maximum resolution': '1920 x 1080'},
#  '53': {'Title': 'hp 14-cf2502sa 14" full hd laptop quad core intel i5 4gb 256gb ssd 16gb optane',
#   'Link': 'https://www.ebay.com.sg/itm/HP-14-cf2502sa-14-Full-HD-Laptop-Quad-Core-Intel-i5-4GB-256GB-SSD-16GB-Optane/303873278527?hash=item46c042423f%3Ag%3AYWYAAOSwuMxgAibj&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '851.95',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Operating system': 'windows 10',
#   'Maximum resolution': '1920 x 1080',
#   'Features': 'built-in microphone, built-in webcam, bluetooth, multi-touch trackpad',
#   'Model': '14-cf2502sa',
#   'Color': 'black',
#   'Ram size': '4 gb',
#   'Screen size': '14 in',
#   'Type': 'notebook/laptop',
#   'Brand': 'hp',
#   'Release year': '2020',
#   'Ssd capacity': '256 gb',
#   'Storage type': 'ssd (solid state drive)',
#   'Processor': 'intel core i5 10th gen.',
#   'Upc': 'does not apply'},
#  '54': {'Title': 'notebook laptop siemens simatic filed pg m 6es7712-1bb10-0ag0 programming device',
#   'Link': 'https://www.ebay.com.sg/itm/Notebook-Laptop-SIEMENS-Simatic-Filed-Pg-M-6ES7712-1BB10-0AG0-Programming-Device/324390977593?hash=item4b87358039%3Ag%3Ak9cAAOSw1T1eSp4U&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '1575.75',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Operating system': 'windows xp',
#   'Hard drive capacity': '80gb',
#   'Memory ram': '128mb',
#   'Ssd hard drive capacity': 'not applicable',
#   'Mpn': '6es7712-1bb10-0ag0',
#   'Product line': 'simatic',
#   'Screen size': '15 zoll (38,5 cm)',
#   'Model': 'filed pg m',
#   'Hard drive type': 'hdd (hard disk drive)',
#   'Type': 'netbook/notebook/laptop',
#   'Ean': '7427055325316',
#   'Brand': 'siemens',
#   'Processor speed': '2ghz',
#   'Processor type': 'intel pentium iii',
#   'Processor': 'does not apply',
#   'Upc': 'does not apply',
#   'Graphic processor': 'integrated graphic'},
#  '55': {'Title': 'notebook laptop siemens simatic filed pg m 6es7712-1bb10-0ag programmer 10',
#   'Link': 'https://www.ebay.com.sg/itm/Notebook-Laptop-SIEMENS-Simatic-Filed-Pg-M-6ES7712-1BB10-0AG-Programmer-10/324390977622?hash=item4b87358056%3Ag%3AB5EAAOSwf2Zd4T6b&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '1274.01',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Operating system': 'windows xp',
#   'Hard drive capacity': '80gb',
#   'Memory ram': '128mb',
#   'Ssd hard drive capacity': 'not applicable',
#   'Mpn': '6es7712-1bb10-0ag0',
#   'Product line': 'simatic',
#   'Screen size': '15 zoll (38,5 cm)',
#   'Model': 'filed pg m',
#   'Hard drive type': 'hdd (hard disk drive)',
#   'Type': 'netbook/notebook/laptop',
#   'Ean': '7427055325316',
#   'Brand': 'siemens',
#   'Processor speed': '2ghz',
#   'Processor type': 'intel pentium iii',
#   'Processor': 'does not apply',
#   'Upc': 'does not apply',
#   'Graphic processor': 'integrated graphic'},
#  '56': {'Title': 'dell latitude 14 7414 rugged extreme laptop i7-6600u 32gb 2tb sshd a-gps 4g lte',
#   'Link': 'https://www.ebay.com.sg/itm/Dell-Latitude-14-7414-Rugged-Extreme-Laptop-i7-6600U-32GB-2TB-SSHD-A-GPS-4G-LTE/164210601415?hash=item263bb6edc7%3Ag%3AR5YAAOSwfM9dabFo&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '3055.08',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Modified item': 'no',
#   'Screen size': '14in.',
#   'Custom bundle': 'no',
#   'Product line': 'latitude',
#   'Memory': '32gb',
#   'Model': '7414',
#   'Operating system edition': 'professional',
#   'Processor': 'does not apply',
#   'Type': 'notebook/laptop',
#   'Features': 'touchscreen, mobile broadband [4g lte], bluetooth, a-gps, triple rf - passthough, backlit keyboard',
#   'Processor speed': '2.30ghz',
#   'Mpn': '7414',
#   'Operating system': 'windows 10',
#   'Non-domestic product': 'no',
#   'Storage type': 'sshd (solid state hybrid drive)',
#   'Processor type': 'intel core i7 6th gen.',
#   'Brand': 'dell',
#   'Optical drive': 'none',
#   'Ssd capacity': '2tb',
#   'Release year': '2016',
#   'Hardware connectivity': 'displayport',
#   'Upc': 'does not apply'},
#  '57': {'Title': 'dell latitude e6410 business laptop pc core i5 4gb 160gb dvd-rw windows 10 pro',
#   'Link': 'https://www.ebay.com.sg/itm/Dell-Latitude-E6410-Business-Laptop-PC-Core-i5-4GB-160GB-DVD-RW-Windows-10-Pro/114615113705?hash=item1aaf97d7e9%3Ag%3A%7E1oAAOSwH-Bf9OTm&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '245.0',
#   'Description': ''},
#  '58': {'Title': 'medion erazer p15609 gaming laptop 15.6" full hd i7-9750h hexa core 512gb 8gb',
#   'Link': 'https://www.ebay.com.sg/itm/Medion-Erazer-P15609-Gaming-Laptop-15-6-Full-HD-i7-9750H-Hexa-Core-512GB-8GB/303887687188?hash=item46c11e1e14%3Ag%3AKToAAOSw%7EQ9gKqcB&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '1471.64',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Modified item': 'no',
#   'Screen size': '15.6 in full hd',
#   'Custom bundle': 'no',
#   'Gpu': '4 gb gddr5 nvidia geforce gtx 1650',
#   'Maximum resolution': '1920 x 1080',
#   'Model': 'p15609-md61737',
#   'Ram size': '8 gb',
#   'Processor': 'intel core i7 9th gen.',
#   'Type': 'notebook/laptop',
#   'Graphics processing type': 'dedicated graphics',
#   'Processor speed': '2.60 ghz',
#   'Features': 'backlit keyboard, wi-fi, built-in webcam, bluetooth',
#   'Operating system': 'windows 10',
#   'Color': 'black',
#   'Storage type': 'ssd (solid state drive)',
#   'Non-domestic product': 'no',
#   'Brand': 'medion',
#   'Most suitable for': 'graphic design, workstation, serious gaming, casual computing, light gaming',
#   'Ssd capacity': '512 gb',
#   'Upc': 'does not apply',
#   'Connectivity': 'usb 2.0, usb 3.0, hdmi'},
#  '59': {'Title': 'asus vivobook slim s330fa 13.3" full hd quad core i7-8565u 8gb 512gb ssd laptop',
#   'Link': 'https://www.ebay.com.sg/itm/ASUS-VivoBook-Slim-S330FA-13-3-Full-HD-Quad-Core-i7-8565U-8GB-512GB-SSD-Laptop/303864474118?hash=item46bfbbea06%3Ag%3A9CAAAOSwCXVeML82&LH_BIN=1&LH_ItemCondition=2500',
#   'Price': '981.59',
#   'Description': '',
#   'Condition': 'remanufactured',
#   'Release year': '2019',
#   'Maximum resolution': '1920 x 1080',
#   'Mpn': 's330faey038t',
#   'Manufacturer warranty': 'other: see item description',
#   'Graphics processing type': 'integrated/on-board graphics',
#   'Most suitable for': 'casual computing',
#   'Features': 'built-in microphone, built-in webcam, bluetooth, multi-touch trackpad',
#   'Operating system': 'windows 10',
#   'Color': 'silver',
#   'Model': 'asus vivobook slim',
#   'Type': 'notebook/laptop',
#   'Ram size': '8 gb',
#   'Brand': 'asus',
#   'Screen size': '13.3 in',
#   'Processor speed': '4.10 ghz',
#   'Manufacturer colour': 'silver',
#   'Ssd capacity': '512 gb',
#   'Storage type': 'ssd (solid state drive)',
#   'Processor': 'intel core i7 8th gen.',
#   'Upc': 'does not apply',
#   'Connectivity': 'usb 2.0, usb 3.1, hdmi'}}

# %%
reebelo_storage
# Out:
# {'1': {'Title': 'refurbished lenovo thinkpad x250 touch 240gb',
#   'Link': 'https://www.reebelo.com/collections/all/products/refurbished-lenovo-thinkpadx250touch-black-240gb-caslam9fhj',
#   'Price': '649',
#   'Description': '',
#   'Condition': 'mint',
#   'Keyboard language': 'english (us)',
#   'Keyboard type': 'qwerty',
#   'Screen size (inches)': '13',
#   'Resolution': '',
#   'Storage (gb)': '240',
#   'Memory (gb)': '8',
#   'Storage type': 'ssd',
#   'Bluetooth': 'yes',
#   'Webcam': 'yes',
#   'Hard drive interface': '',
#   'Memory type': '',
#   'Processor speed (ghz)': '',
#   'Processor brand': 'intel',
#   'Processor type': 'i5-5300u',
#   'Processor core': '',
#   'Graphic card type': '',
#   'Graphic card memory type': '',
#   'Os': 'windows 10',
#   'Network': '',
#   'Backlit keyboard': '',
#   'Color': 'black',
#   'Processor': 'intel core i5-5300u',
#   'Ports': '',
#   'Manufacturer ref': 'lenovo thinkpad x250 touch'},
#  '2': {'Title': 'refurbished lenovo thinkpad t460',
#   'Link': 'https://www.reebelo.com/collections/all/products/lenovo-thinkpad-t460-black-500gb-hdd-14-inch-i5-6200u-8gb-ram-very-good-condition',
#   'Price': '643',
#   'Description': ''},
#  '3': {'Title': "refurbished dell latitude e7280 12.5' / core i57300u 2.6ghz/ 8gb ram / 512gb ssd【 microsoft authorised refurbisher 】",
#   'Link': 'https://www.reebelo.com/collections/all/products/dell-latitude-e7280-12-5-core-i5-7300u-2-6ghz-8gb-ram-512gb-ssd-microsoft-authorised-refurbisher',
#   'Price': '649',
#   'Description': '',
#   'Model': 'dell latitude e7280',
#   'Cpu': 'intel core i5 (7th gen) 7300u / 2.6 ghz',
#   'Number of cores': 'dual core',
#   'Max supported size': '16gb ram',
#   'Installed size': '8gb',
#   'Hard drive capacity': '512gb ssd',
#   'Lcd backlight technology': 'wled backlight',
#   'Monitor features': 'anti-glare',
#   'Graphics processor': 'intel hd graphics 520',
#   'Integrated webcam': 'yes',
#   'Sound': 'speakers, microphone',
#   'Data link protocol': 'bluetooth 4.2, ethernet, fast ethernet, gigabit ethernet, ieee 802.11a, ieee 802.11ac, ieee 802.11b, ieee 802.11g, ieee 802.11n',
#   'Connection interfaces': '2 x usb 3.0, 1 x usb-c, lan, headphone/microphone combo jack, hdmi',
#   'Monitor size': '12.5in',
#   'Dimension (wxdxh)': '12 x 8.2 x 0.7 in',
#   'Weight': '2.6 lbs',
#   'Operating system': 'microsoft windows 10 pro 64-bit'},
#  '4': {'Title': 'refurbished lenovo thinkpad yoga 370 (touchscreen)',
#   'Link': 'https://www.reebelo.com/collections/all/products/lenovo-thinkpad-yoga-370-touchscreen-i5-7300u-256gb-ssd-8gb-ram-silver-mint-condition',
#   'Price': '1,029',
#   'Description': '',
#   'Model': 'lenovo thinkpad yoga 370 (silver) (touchscreen)',
#   'Processor': 'intel core i5-7300u',
#   'Ram': '8gb',
#   'Storage': '256gb ssd',
#   'Os': 'windows 10'},
#  '5': {'Title': 'refurbished dell latitude e7470',
#   'Link': 'https://www.reebelo.com/collections/all/products/39267-used-and-refurbished-secondhand-dell-latitudee7470-black-256gbssd-singapore',
#   'Price': '809',
#   'Description': '',
#   'Keyboard language': '1399',
#   'Screen size (inches)': 'english (us)',
#   'Resolution': 'qwerty',
#   'Storage (gb)': '14',
#   'Storage type': '256',
#   'Bluetooth': '8',
#   'Webcam': 'ssd',
#   'Hard drive interface': 'yes',
#   'Memory type': 'yes',
#   'Processor core': 'intel',
#   'Graphic card type': 'i7-6600u',
#   'Backlit keyboard': 'windows 10',
#   'Ports': 'black',
#   'Manufacturer ref': 'intel core i7-6600u',
#   '': 'dell latitude e7470'},
#  '6': {'Title': 'refurbished dell latitude e5470 256gb',
#   'Link': 'https://www.reebelo.com/collections/all/products/refurbished-dell-latitudee5470-silver-256gb-caslab1pfb',
#   'Price': '849',
#   'Description': '',
#   'Condition': 'mint',
#   'Keyboard language': 'english (us)',
#   'Keyboard type': 'qwerty',
#   'Screen size (inches)': '14',
#   'Resolution': '',
#   'Storage (gb)': '256',
#   'Memory (gb)': '8',
#   'Storage type': 'ssd',
#   'Bluetooth': 'yes',
#   'Webcam': 'yes',
#   'Hard drive interface': '',
#   'Memory type': '',
#   'Processor speed (ghz)': '',
#   'Processor brand': 'intel',
#   'Processor type': 'i5-6300u',
#   'Processor core': '',
#   'Graphic card type': '',
#   'Graphic card memory type': '',
#   'Os': 'windows 10',
#   'Network': '',
#   'Backlit keyboard': '',
#   'Color': 'black',
#   'Processor': 'intel core i5-6300u',
#   'Ports': '',
#   'Manufacturer ref': 'dell latitude e5470'},
#  '7': {'Title': 'refurbished lenovo thinkpad t440p',
#   'Link': 'https://www.reebelo.com/collections/all/products/lenovo-thinkpad-t440p-black-500gb-hdd-14-inch-i7-4600m-8gb-ram-good-condition',
#   'Price': '528',
#   'Description': ''},
#  '8': {'Title': 'refurbished dell latitude 7270 128gb',
#   'Link': 'https://www.reebelo.com/collections/all/products/refurbished-dell-latitude7270-silver-128gb-caslaxfasz',
#   'Price': '649',
#   'Description': '',
#   'Condition': 'mint',
#   'Keyboard language': 'english (us)',
#   'Keyboard type': 'qwerty',
#   'Screen size (inches)': '13',
#   'Resolution': '',
#   'Storage (gb)': '128',
#   'Memory (gb)': '8',
#   'Storage type': 'ssd',
#   'Bluetooth': 'yes',
#   'Webcam': 'yes',
#   'Hard drive interface': '',
#   'Memory type': '',
#   'Processor speed (ghz)': '',
#   'Processor brand': 'intel',
#   'Processor type': 'i7-6600u',
#   'Processor core': '',
#   'Graphic card type': '',
#   'Graphic card memory type': '',
#   'Os': 'windows 10',
#   'Network': '',
#   'Backlit keyboard': '',
#   'Color': 'silver',
#   'Processor': 'intel core i7-6600u',
#   'Ports': '',
#   'Manufacturer ref': 'dell latitude e7270'},
#  '9': {'Title': 'refurbished acer travelmate p249',
#   'Link': 'https://www.reebelo.com/collections/all/products/41956-used-and-refurbished-secondhand-acer-travelmatep249-black-500gbhdd-singapore',
#   'Price': '575',
#   'Description': '',
#   'Keyboard type': 'standard',
#   'Screen size (inches)': '14',
#   'Resolution': '1366*768',
#   'Storage (gb)': '500',
#   'Memory (gb)': '8',
#   'Storage type': 'hdd',
#   'Bluetooth': 'yes',
#   'Webcam': 'yes',
#   'Hard drive interface': 'sata',
#   'Memory type': 'ddr4',
#   'Processor speed (ghz)': '2.3',
#   'Processor brand': 'intel',
#   'Processor type': '6200u',
#   'Processor core': 'i5',
#   'Graphic card type': 'intel',
#   'Graphic card memory type': 'intel graphics',
#   'Os': 'win 10',
#   'Network': 'yes',
#   '': 'na',
#   'Color': 'black',
#   'Ports': '3',
#   'Manufacturer ref': 'acer'},
#  '10': {'Title': 'refurbished lenovo thinkpad x240',
#   'Link': 'https://www.reebelo.com/collections/all/products/lenovo-thinkpad-x240-black-500gb-hdd-12-5-inch-i7-4600u-4gb-ram-very-good-condition',
#   'Price': '459',
#   'Description': ''},
#  '11': {'Title': 'refurbished macbook pro a1502',
#   'Link': 'https://www.reebelo.com/collections/all/products/38891-used-and-refurbished-secondhand-apple-macbookproa1502-silver-256gbssd-singapore',
#   'Price': '1,269',
#   'Description': ''},
#  '12': {'Title': 'refurbished dell latitude e7250',
#   'Link': 'https://www.reebelo.com/collections/all/products/dell-latitude-e7250-black-256gb-ssd-13-inch-i7-5600u-8gb-very-good-condition',
#   'Price': '528',
#   'Description': ''},
#  '13': {'Title': "refurbished lenovo thinkpad x280 8th 12.5'' / core i58350u / 8gb ram / 256gb ssd nvme【 microsoft authorised refurbisher 】",
#   'Link': 'https://www.reebelo.com/collections/all/products/lenovo-thinkpad-x280-8th-12-5-core-i5-8350u-8gb-ram-256gb-ssd-nvme-microsoft-authorised-refurbisher',
#   'Price': '868',
#   'Description': '',
#   'Model': 'thinkpad x280 8th (touch screen )',
#   'Cpu': 'intel core i5 (8th gen) 8350u / 1.7 ghz',
#   'Number of cores': 'quad-core',
#   'Ram installed size': '8gb',
#   'Hard drive capacity': '256gb ssd',
#   'Lcd backlight technology': 'led backlight',
#   'Resolution': '1920 x 1080 (full hd)',
#   'Monitor features': 'anti-glare, on-cell touch technology (ips)',
#   'Graphics processor': 'intel uhd graphics 620',
#   'Display resolution': 'full hd',
#   'Sound': 'stereo speakers, dual array microphone',
#   'Data link protocol': 'bluetooth 4.1, ieee 802.11a, ieee 802.11ac,\nieee 802.11b, ieee 802.11g, ieee 802.11n',
#   'Connection interfaces': 'usb 3.1 gen 1 ,usb 3.1 gen 1 (always on) , usb-c 3.1 gen 1 ,\nusb-c 3.1 gen 2/thunderbolt 3 ,hdmi ,lenovo ethernet extension connector ,\ndock ,headphone/microphone combo jack',
#   'Monitor size': '12.5 in',
#   'Dimension (wxdxh)': '12.1 x 8.3 x 0.7 in',
#   'Weight': '2.8 lbs',
#   'Operating system': 'microsoft windows 10 pro 64-bit'},
#  '14': {'Title': 'refurbished dell latitude e7470 touchscreen',
#   'Link': 'https://www.reebelo.com/collections/all/products/dell-latitude-e7470-touchscreen-black-500gb-hdd-14-inch-i7-6600u-8gb-ram-very-good-condition',
#   'Price': '919',
#   'Description': ''},
#  '15': {'Title': 'refurbished hp elitebook 840 g2',
#   'Link': 'https://www.reebelo.com/collections/all/products/hp-elitebook-840-g2-black-500gb-hdd-14-inch-i5-5200u-4gb-ram-very-good-condition',
#   'Price': '574',
#   'Description': ''},
#  '16': {'Title': 'refurbished lenovo thinkpad t540p',
#   'Link': 'https://www.reebelo.com/collections/all/products/81371-used-and-refurbished-secondhand-lenovo-thinkpadt540p-black-500gbhdd-singapore',
#   'Price': '459',
#   'Description': ''},
#  '17': {'Title': 'refurbished hp elitebook 820 g2',
#   'Link': 'https://www.reebelo.com/collections/all/products/hp-elitebook-820-g2-black-256gb-hdd-12-5-inch-i5-5200u-4gb-ram-very-good-condition',
#   'Price': '574',
#   'Description': ''},
#  '18': {'Title': 'brand new hp elitebook 830 g7 13.3" i5 10210u 8gb ram 512gb ssd',
#   'Link': 'https://www.reebelo.com/collections/all/products/brandnew-hp-elitebook830g7-silver-512gb-mobh6v3y',
#   'Price': '1,110',
#   'Description': '',
#   'Model': 'special features'},
#  '19': {'Title': 'refurbished lenovo thinkpad t450s',
#   'Link': 'https://www.reebelo.com/collections/all/products/65491-used-and-refurbished-secondhand-lenovo-thinkpadt450s-black-240gbssd-singapore',
#   'Price': '620',
#   'Description': ''},
#  '20': {'Title': "refurbished hp elitebook 840 g3 / 14'' / core i56300u / 8gbram / 256gb ssd 【 microsoft authorised refurbisher 】",
#   'Link': 'https://www.reebelo.com/collections/all/products/hp-elitebook-840-g3-12-5-core-i5-6300u-8gbram-180-gb-ssd-microsoft-authorised-refurbisher',
#   'Price': '469',
#   'Description': '',
#   'Model': 'hp elitebook 840 g3',
#   'Cpu': 'intel core i5 (6th gen) 6300u / 2.4 ghz',
#   'Number of cores': 'dual core',
#   'Max supported size': '16gb ram',
#   'Installed size': '8gb ddr4',
#   'Hard drive capacity': '256gb ssd',
#   'Lcd backlight technology': 'led backlight monitor',
#   'Features': 'hd standard-viewing angle (sva) edp anti-glare, slim design',
#   'Graphics processor': 'intel hd graphics 520',
#   'Integrated webcam': 'yes',
#   'Display resolution': '1366 x 768 (hd)',
#   'Sound': 'stereo speakers, stereo microphone',
#   'Data link protocol': 'bluetooth 4.2, ethernet, fast ethernet, gigabit ethernet,\nieee 802.11a, ieee 802.11ac, ieee 802.11b, ieee 802.11g, ieee 802.11n, nfc',
#   'Connection interfaces': '2 x usb 3.0 , usb-c , displayport , vga ,lan ,\ndock ,headphone/microphone combo jack',
#   'Monitor size': '12.5 in / 14in',
#   'Dimension (wxdxh)': '12.2 x 8.6 x 0.7 in / 13.3 x 9.3 x 0.7 in',
#   'Weight': '2.978lbs / 3.4ibs',
#   'Operating system': 'microsoft windows 10 pro 64-bit'},
#  '21': {'Title': 'refurbished dell inspiron 15 (3576)',
#   'Link': 'https://www.reebelo.com/collections/all/products/14345-used-and-refurbished-secondhand-dell-inspiron153576-black-240gbssd-singapore',
#   'Price': '719',
#   'Description': '',
#   'Model': 'inspiron 15',
#   'Keyboard language': 'english (us)',
#   'Keyboard type': 'qwerty',
#   'Screen size (inches)': '15',
#   'Resolution': '1920 x 1080',
#   'Storage (gb)': '240',
#   'Memory (gb)': '8',
#   'Storage type': 'ssd',
#   'Bluetooth': 'yes',
#   'Webcam': 'yes',
#   'Memory type': 'ddr4',
#   'Processor brand': 'intel',
#   'Processor type': 'i5-8250u',
#   'Graphic card type': 'amd radeon 520',
#   'Graphic card memory type': '2gb gddr5',
#   'Os': 'windows 10',
#   'Processor': 'inter core i5-8250u',
#   'Ports': '2x usb type-a 3.0; 1x usb type-a 2.0; hdmi 1.4b; card reader; audio jack',
#   'Manufacturer ref': '3576'},
#  '22': {'Title': "refurbished dell latitude e7270 12.5'' / core i5 6300u / 8gbram / 256gb ssd 【 microsoft authorised refurbisher 】",
#   'Link': 'https://www.reebelo.com/collections/all/products/dell-latitude-e7270-12-5-core-i5-6300u-8gbram-256gb-ssd-microsoft-authorised-refurbisher',
#   'Price': '569',
#   'Description': '',
#   'Model': 'dell latitude e7270',
#   'Cpu': 'intel core i5 (6th gen) 6300u / 2.6 ghz',
#   'Number of cores': 'dual core',
#   'Max supported size': '16gb ram',
#   'Installed size': '8gb',
#   'Hard drive capacity': '256gb ssd',
#   'Lcd backlight technology': 'wled backlight',
#   'Monitor features': 'anti-glare',
#   'Graphics processor': 'intel hd graphics 520',
#   'Integrated webcam': 'yes',
#   'Sound': 'speakers, microphone',
#   'Data link protocol': 'bluetooth 4.2, ethernet, fast ethernet, gigabit ethernet, ieee 802.11a, ieee 802.11ac, ieee 802.11b, ieee 802.11g, ieee 802.11n',
#   'Connection interfaces': '2 x usb 3.0,lan,headphone/microphone combo jack,hdmi,mini displayport dock ,usb 3.0 (powershare)',
#   'Monitor size': '12.5in',
#   'Dimension (wxdxh)': '12.2 x 8.5 x 0.7 in',
#   'Weight': '2.78 lbs',
#   'Operating system': 'microsoft windows 10 pro 64-bit'},
#  '23': {'Title': 'refurbished lenovo thinkpad x1 yoga 1st gen (touchscreen)',
#   'Link': 'https://www.reebelo.com/collections/all/products/lenovo-thinkpad-x1-yoga-1st-gen-touchscreen-i5-6300u-256gb-ssd-8gb-ram-black-mint-condition',
#   'Price': '929',
#   'Description': '',
#   'Model': 'lenovo thinkpad x1 yoga g1 (black) (touchscreen)',
#   'Processor': 'intel core i5-6300u',
#   'Ram': '8gb',
#   'Storage': '256gb ssd',
#   'Os': 'windows 10'},
#  '24': {'Title': 'refurbished lenovo thinkpad t460s',
#   'Link': 'https://www.reebelo.com/collections/all/products/lenovo-thinkpad-t460s-black-256gb-ssd-14-inch-i7-6600u-8gb-ram-very-good-condition',
#   'Price': '689',
#   'Description': ''},
#  '25': {'Title': 'refurbished lenovo thinkpad x260',
#   'Link': 'https://www.reebelo.com/collections/all/products/56042-used-and-refurbished-secondhand-lenovo-thinkpadx260-black-500gbhdd-singapore',
#   'Price': '597',
#   'Description': ''},
#  '26': {'Title': "refurbished lenovo thinkpad x1 yoga 1st gen ultrabook (touch screen 360° flip design) 13.1'' / core i76600u / 16gb ram / 256gb ssd【 microsoft authorised refurbisher 】",
#   'Link': 'https://www.reebelo.com/collections/all/products/lenovo-thinkpad-x1-yoga-1st-gen-ultrabook-touch-screen-360-flip-design-13-1-core-i7-6600u-16gb-ram-256gb-ssd-microsoft-authorised-refurbisher',
#   'Price': '849',
#   'Description': '',
#   'Model': 'thinkpad x1 yoga gen 1 ultrabook (touch screen 360° flip design)',
#   'Cpu': 'intel core i7 (6th gen) 6600u / 2.60ghz',
#   'Number of cores': '256gb ssd',
#   'Ram installed size': '2x 8gb',
#   'Hard drive capacity': '256gb ssd',
#   'Lcd backlight technology': 'led backlight',
#   'Resolution': '1920 x 1080 (full hd)',
#   'Monitor features': 'anti-glare',
#   'Graphics processor': 'intel hd graphics 520',
#   'Display resolution': 'full hd',
#   'Sound': 'stereo speakers, dual array microphone',
#   'Data link protocol': 'bluetooth 4.1, ieee 802.11a, ieee 802.11ac, ieee 802.11b, ieee 802.11g, ieee 802.11n',
#   'Connection interfaces': '3 x usb 3.0, mini displayport, hdmi, headphone/microphone combo jack, onelink+ connector',
#   'Monitor size': '14 in',
#   'Dimension (wxdxh)': '13.1 x 9 x 0.7 in',
#   'Weight': '3 lbs',
#   'Operating system': 'microsoft windows 10 pro 64-bit'},
#  '27': {'Title': 'refurbished dell latitude e7450',
#   'Link': 'https://www.reebelo.com/collections/all/products/dell-latitude-e7450-black-256gb-ssd-14-inch-i7-5600u-8gb-very-good-condition',
#   'Price': '758',
#   'Description': ''},
#  '28': {'Title': 'refurbished asus zenbook ux331un 13 touch 512gb',
#   'Link': 'https://www.reebelo.com/collections/all/products/refurbished-asus-zenbookux331un13touch-blue-512gb-caslahqhow',
#   'Price': '1,299',
#   'Description': '',
#   'Condition': 'mint',
#   'Keyboard language': 'english (us)',
#   'Keyboard type': 'qwerty',
#   'Screen size (inches)': '13',
#   'Resolution': '',
#   'Storage (gb)': '512',
#   'Memory (gb)': '16',
#   'Storage type': 'ssd',
#   'Bluetooth': 'yes',
#   'Webcam': 'yes',
#   'Hard drive interface': '',
#   'Memory type': '',
#   'Processor speed (ghz)': '',
#   'Processor brand': 'intel',
#   'Processor type': 'i7-8550u',
#   'Processor core': '',
#   'Graphic card type': 'mx150',
#   'Graphic card memory type': '',
#   'Os': 'windows 10',
#   'Network': '',
#   'Backlit keyboard': '',
#   'Color': 'blue',
#   'Processor': 'intel core i7-8550u',
#   'Ports': '',
#   'Manufacturer ref': 'asus zenbook 13 touch'},
#  '29': {'Title': 'refurbished dell latitude e7440',
#   'Link': 'https://www.reebelo.com/collections/all/products/dell-latitude-e7440-black-256gb-ssd-14-inch-i7-4600u-8gb-very-good-condition',
#   'Price': '597',
#   'Description': ''},
#  '30': {'Title': 'refurbished lenovo thinkpad x260',
#   'Link': 'https://www.reebelo.com/collections/all/products/lenovo-thinkpad-x260-black-500gb-hdd-12-5-inch-i5-6200u-4gb-ram-very-good-condition',
#   'Price': '540',
#   'Description': ''},
#  '31': {'Title': "refurbished lenovo thinkpad x1 carbon 6th gen 14'' / core i58350u / 8gb ram / 256gb ssd nvme【 microsoft authorised refurbisher 】",
#   'Link': 'https://www.reebelo.com/collections/all/products/lenovo-thinkpad-x1-carbon-6th-gen-14-core-i5-8350u-8gb-ram-256gb-ssd-nvme-microsoft-authorised-refurbisher',
#   'Price': '1,068',
#   'Description': '',
#   'Model': 'thinkpad x1 carbon 6th (touch screen )',
#   'Cpu': 'intel core i5 (8th gen) 8350u / 1.7 ghz',
#   'Number of cores': 'quad-core',
#   'Ram installed size': '8gb',
#   'Hard drive capacity': '256gb ssd',
#   'Lcd backlight technology': 'led backlight',
#   'Resolution': '1920 x 1080 (full hd)',
#   'Monitor features': '72% color gamut, anti-glare (ips)',
#   'Graphics processor': 'intel uhd graphics 620',
#   'Display resolution': 'full hd',
#   'Sound': 'stereo speakers, dual array microphone',
#   'Data link protocol': 'bluetooth 4.1, ieee 802.11a, ieee 802.11ac,\nieee 802.11b, ieee 802.11g, ieee 802.11n',
#   'Connection interfaces': 'usb 3.1 gen 1 ,usb 3.1 gen 1 (always on),\n2 x usb-c 3.1 gen 2/thunderbolt 3/displayport (power delivery),\nhdmi , headphone/microphone combo jack,lenovo ethernet\nextension connector dock',
#   'Monitor size': '14 in',
#   'Dimension (wxdxh)': '12.7.2 x 8.5 x 0.9 in',
#   'Weight': '2.49 lbs',
#   'Operating system': 'microsoft windows 10 pro 64-bit'},
#  '32': {'Title': 'refurbished dell latitude e5470 / 14" / core i56300u / 8gbram / ssd【 microsoft authorised refurbisher 】',
#   'Link': 'https://www.reebelo.com/collections/all/products/dell-latitude-e5470-14-core-i5-6300u-8gbram-256gbssd-microsoft-authorised-refurbisher',
#   'Price': '499',
#   'Description': '',
#   'Model': 'dell latitude e5470',
#   'Cpu': 'intel core i5 (6th gen) 6440hq / 2.6 ghz',
#   'Number of cores': 'dual core',
#   'Max supported size': '16gb ram',
#   'Installed size': '8gb',
#   'Hard drive capacity': '256gb ssd',
#   'Lcd backlight technology': 'wled backlight',
#   'Monitor features': 'anti-glare',
#   'Graphics processor': 'intel hd graphics 520',
#   'Integrated webcam': 'yes',
#   'Sound': 'speakers, microphone',
#   'Data link protocol': 'bluetooth 4.1, ethernet, fast ethernet, gigabit ethernet, ieee 802.11a,\nieee 802.11ac, ieee 802.11b, ieee 802.11g, ieee 802.11n',
#   'Connection interfaces': '3 x usb 3.0, vga, lan, headphone/microphone combo jack, hdmi,dock',
#   'Monitor size': '14in',
#   'Dimension (wxdxh)': '13.2 x 9.1 x 0.9 in',
#   'Weight': '3.88 lbs',
#   'Operating system': 'microsoft windows 10 pro 64-bit'},
#  '33': {'Title': 'refurbished lenovo thinkpad t440p',
#   'Link': 'https://www.reebelo.com/collections/all/products/59191-used-and-refurbished-secondhand-lenovo-thinkpadt440p-black-500gbhdd-singapore',
#   'Price': '439',
#   'Description': ''},
#  '34': {'Title': 'refurbished fujitsu lifebook e546',
#   'Link': 'https://www.reebelo.com/collections/all/products/fujitsu-lifebook-e546-intel-core-i3-6100u-128gb-ssd-8gb-ram-black-mint-condition',
#   'Price': '429',
#   'Description': '',
#   'Model': 'fujitsu notebook lifebook e546 (black)',
#   'Processor': 'intel core i3-6100u',
#   'Ram': '8gb',
#   'Storage': '128gb ssd',
#   'Os': 'windows 10'},
#  '35': {'Title': 'refurbished lenovo thinkpad x240',
#   'Link': 'https://www.reebelo.com/collections/all/products/lenovo-thinkpad-x240-black-128gb-ssd-12-5-inch-i7-4600u-4gb-ram-very-good-condition',
#   'Price': '459',
#   'Description': ''},
#  '36': {'Title': 'refurbished lenovo thinkpad t460 touch 256gb',
#   'Link': 'https://www.reebelo.com/collections/all/products/refurbished-lenovo-thinkpadt460touch-black-256gb-caslassp8i',
#   'Price': '849',
#   'Description': '',
#   'Condition': 'mint',
#   'Keyboard language': 'english (us)',
#   'Keyboard type': 'qwerty',
#   'Screen size (inches)': '14',
#   'Resolution': '',
#   'Storage (gb)': '256',
#   'Memory (gb)': '8',
#   'Storage type': 'ssd',
#   'Bluetooth': 'yes',
#   'Webcam': 'yes',
#   'Hard drive interface': '',
#   'Memory type': '',
#   'Processor speed (ghz)': '',
#   'Processor brand': 'intel',
#   'Processor type': 'i5-6300u',
#   'Processor core': '',
#   'Graphic card type': '',
#   'Graphic card memory type': '',
#   'Os': 'windows 10',
#   'Network': '',
#   'Backlit keyboard': '',
#   'Color': 'black',
#   'Processor': 'intel core i5-6300u',
#   'Ports': '',
#   'Manufacturer ref': 'lenovo thinkpad t460 touch'},
#  '37': {'Title': 'refurbished lenovo thinkpad t460',
#   'Link': 'https://www.reebelo.com/collections/all/products/lenovo-thinkpad-t460-black-500gb-hdd-14-inch-i5-6200u-4gb-ram-very-good-condition',
#   'Price': '586',
#   'Description': ''},
#  '38': {'Title': 'refurbished lenovo thinkpad l560',
#   'Link': 'https://www.reebelo.com/collections/all/products/lenovo-thinkpad-l560-black-500gb-hdd-15-6-inch-i5-6300u-8gb-ram-very-good-condition',
#   'Price': '688',
#   'Description': ''},
#  '39': {'Title': 'refurbished hp zbook 15 g3',
#   'Link': 'https://www.reebelo.com/collections/all/products/hp-zbook-15-g3-i7-6820hq-512gb-ssd-1tb-hdd-15-6-32gb-ram-black-mint-condition',
#   'Price': '1,529',
#   'Description': '',
#   'Model': 'hp zbook 15 g3 mobile workstation laptop',
#   'Processor': 'intel core i7-6820hq',
#   'Ram': '32gb',
#   'Storage': '512gb ssd + 1tb hdd',
#   'Os': 'windows 10',
#   'Gpu': 'nvidia quadro m2000m with 4 gb dedicated gddr5\nvideo memory microsoft directx 12 (shader model 5.0) and opengl 4.4 capable'},
#  '40': {'Title': "refurbished dell latitude e7280 12.5' / core i57300u 2.6ghz/ 8gb ram / 128gb ssd【 microsoft authorised refurbisher 】",
#   'Link': 'https://www.reebelo.com/collections/all/products/dell-latitude-e7280-12-5-core-i5-7300u-2-6ghz-8gb-ram-128gb-ssd-microsoft-authorised-refurbisher',
#   'Price': '599',
#   'Description': '',
#   'Model': 'dell latitude e7280',
#   'Cpu': 'intel core i5 (7th gen) 7300u / 2.6 ghz',
#   'Number of cores': 'dual core',
#   'Max supported size': '16gb ram',
#   'Installed size': '8gb',
#   'Hard drive capacity': '128gb ssd',
#   'Lcd backlight technology': 'wled backlight',
#   'Monitor features': 'anti-glare',
#   'Graphics processor': 'intel hd graphics 520',
#   'Integrated webcam': 'yes',
#   'Sound': 'speakers, microphone',
#   'Data link protocol': 'bluetooth 4.2, ethernet, fast ethernet, gigabit ethernet, ieee 802.11a, ieee 802.11ac, ieee 802.11b, ieee 802.11g, ieee 802.11n',
#   'Connection interfaces': '2 x usb 3.0, 1 x usb-c, lan, headphone/microphone combo jack, hdmi',
#   'Monitor size': '12.5in',
#   'Dimension (wxdxh)': '12 x 8.2 x 0.7 in',
#   'Weight': '2.6 lbs',
#   'Operating system': 'microsoft windows 10 pro 64-bit'},
#  '41': {'Title': 'refurbished lenovo thinkpad t440s',
#   'Link': 'https://www.reebelo.com/collections/all/products/lenovo-thinkpad-t440s-black-240gb-ssd-14-inch-i5-4200u-8gb-ram-good-condition',
#   'Price': '643',
#   'Description': ''},
#  '42': {'Title': 'refurbished hp elitebook folio 1040 g3 256gb',
#   'Link': 'https://www.reebelo.com/collections/all/products/refurbished-hp-elitebookfolio1040g3-silver-256gb-caslarkodk',
#   'Price': '949',
#   'Description': '',
#   'Condition': 'mint',
#   'Keyboard language': 'english (us)',
#   'Keyboard type': 'qwerty',
#   'Screen size (inches)': '14',
#   'Resolution': '',
#   'Storage (gb)': '256',
#   'Memory (gb)': '8',
#   'Storage type': 'ssd',
#   'Bluetooth': 'yes',
#   'Webcam': 'yes',
#   'Hard drive interface': '',
#   'Memory type': '',
#   'Processor speed (ghz)': '',
#   'Processor brand': 'intel',
#   'Processor type': 'i7-6600u',
#   'Processor core': '',
#   'Graphic card type': '',
#   'Graphic card memory type': '',
#   'Os': 'windows 10',
#   'Network': '',
#   'Backlit keyboard': '',
#   'Color': 'silver',
#   'Processor': 'intel core i7-6600u',
#   'Ports': '',
#   'Manufacturer ref': 'hp elitebook folio 1040 g3'},
#  '43': {'Title': "refurbished hp elitebook 820 g3 / 12.5'' / core i56300u / 8gbram / 180 gb ssd 【 microsoft authorised refurbisher 】",
#   'Link': 'https://www.reebelo.com/collections/all/products/hp-elitebook-820-g3-12-5-core-i5-6300u-8gbram-180-gb-ssd-microsoft-authorised-refurbisher',
#   'Price': '399',
#   'Description': '',
#   'Model': 'hp elitebook 820 g3',
#   'Cpu': 'intel core i5 (6th gen) 6300u / 2.4 ghz',
#   'Number of cores': 'dual core',
#   'Max supported size': '16gb ram',
#   'Installed size': '8gb ddr4',
#   'Hard drive capacity': '180 gb ssd',
#   'Lcd backlight technology': 'led backlight',
#   'Monitor features': 'hd standard-viewing angle (sva) edp anti-glare, slim design',
#   'Graphics processor': 'intel hd graphics 520',
#   'Integrated webcam': 'yes',
#   'Display resolution': '1366 x 768 (hd)',
#   'Sound': 'stereo',
#   'Speakers, stereo microphone data link protocol': 'bluetooth 4.2, ethernet,\nfast ethernet, gigabit ethernet, ieee 802.11a, ieee 802.11ac, ieee 802.11b,\nieee 802.11g, ieee 802.11n, nfc',
#   'Connection interfaces': '2 x usb 3.0 , usb-c , displayport , vga ,lan ,\ndock ,headphone/microphone combo jack',
#   'Monitor size': '12.5 in / 14in',
#   'Dimension (wxdxh)': '12.2 x 8.6 x 0.7 in / 13.3 x 9.3 x 0.7 in',
#   'Weight': '2.978lbs / 3.4ibs',
#   'Operating system': 'microsoft windows 10 pro 64-bit'},
#  '44': {'Title': 'refurbished lenovo thinkpad p50 256gb',
#   'Link': 'https://www.reebelo.com/collections/all/products/refurbished-lenovo-thinkpadp50-black-256gb-caslahqhow',
#   'Price': '1,149',
#   'Description': '',
#   'Condition': 'mint',
#   'Keyboard language': 'english (us)',
#   'Keyboard type': 'qwerty',
#   'Screen size (inches)': '15',
#   'Resolution': '',
#   'Storage (gb)': '256',
#   'Memory (gb)': '8',
#   'Storage type': 'ssd',
#   'Bluetooth': 'yes',
#   'Webcam': 'yes',
#   'Hard drive interface': '',
#   'Memory type': '',
#   'Processor speed (ghz)': '',
#   'Processor brand': 'intel',
#   'Processor type': 'i7-8565u',
#   'Processor core': '',
#   'Graphic card type': '',
#   'Graphic card memory type': 'quadro m1000m',
#   'Os': 'windows 10',
#   'Network': '',
#   'Backlit keyboard': '',
#   'Color': 'black',
#   'Processor': 'intel core i7-8565u',
#   'Ports': '',
#   'Manufacturer ref': 'lenovo thinkpad p50'},
#  '45': {'Title': 'refurbished dell latitude 5480 256gb',
#   'Link': 'https://www.reebelo.com/collections/all/products/refurbished-dell-latitude5480-black-256gb-casla2fgn7',
#   'Price': '649',
#   'Description': '',
#   'Condition': 'mint',
#   'Keyboard language': 'english (us)',
#   'Keyboard type': 'qwerty',
#   'Screen size (inches)': '14',
#   'Resolution': '',
#   'Storage (gb)': '256',
#   'Memory (gb)': '8',
#   'Storage type': 'ssd',
#   'Bluetooth': 'yes',
#   'Webcam': 'yes',
#   'Hard drive interface': '',
#   'Memory type': '',
#   'Processor speed (ghz)': '',
#   'Processor brand': 'intel',
#   'Processor type': 'i5-6440hq',
#   'Processor core': '',
#   'Graphic card type': '',
#   'Graphic card memory type': '',
#   'Os': 'windows 10',
#   'Network': '',
#   'Backlit keyboard': '',
#   'Color': 'black',
#   'Processor': 'intel core i5-6440hq',
#   'Ports': '',
#   'Manufacturer ref': 'dell latitude 5480'}}

# %%
df_ebay = pd.DataFrame.from_dict(ebay_storage, orient='index')
df_ebay
# Out:
#                                                 Title  \
# 1   dell latitude 5404 rugged extreme laptop i7-46...
# 2   asus zenbook ux31a ultrabook 13.3" full hd i7-...
# 3   notebook laptop siemens simatic filed pg 6es77...
# 4   hp 14-cf1502sa 14" full hd laptop intel quad c...
# 5   hp 15s-eq1510sa 15.6" full hd laptop amd ryzen...
# 6   notebook laptop siemens simatic filed pg m 6es...
# 7   acer nitro 5 an515 15.6" full hd intel quad co...
# 8   lenovo yoga s730 13.3" full hd laptop quad cor...
# 9   laptop computer lenovo l412 i3 4gb 120gb ssd 1...
# 10  hp 14-cf2503sa 14" full hd intel quad core i5-...
# 11  dell latitude 14 7414 rugged extreme laptop i5...
# 12  notebook laptop siemens simatic filed pg 6es77...
# 13  linux laptop | dell latitude e6420 14" ubuntu ...
# 14  laptop computer lenovo x230 i5 10892 5/12ft 2,...
# 15  lenovo ideapad l340 15.6" gaming laptop intel ...
# 16  hp pavilion 14-ce3600sa 14" full hd intel core...
# 17  laptop computer hp 8570p i5 10531 6/12ft 8gb 1...
# 18  lenovo ideapad 5i 14iil05 14" full hd laptop i...
# 19  asus c302ca laptop google chromebook lightweig...
# 20  aftershock apex 15 gaming laptop i7-8750h gtx ...
# 21  msi gf75 thin 17.3” gaming laptop hexa core in...
# 22  laptop black fusitsu siemens lifebook s2110 fs...
# 23  hp 14s-dq1505sa 14" ips wled full hd laptop in...
# 24  dell latitude 14 7414 rugged extreme laptop i7...
# 25  lenovo ideapad 530s-14arr 14" full hd amd ryze...
# 26  apple macbook pro 15" 2014 retina a1398 laptop...
# 27  asus zenbook ux305fa 13.3" full hd m-5y10 8gb ...
# 28  notebook laptop siemens simatic filed pg m 6es...
# 29  asus tp410u 14 inch fhd laptop 8th gen i5-8250...
# 30  laptop computer lenovo x240 i5 14107 7/12ft 2,...
# 31  retro notebook compaq armada 4150 pentium 150m...
# 32  hp pavilion 15-cw1598sa 15.6" touchscreen lapt...
# 33  acer acernote light 370pcx case motherboard la...
# 34  hp 255 g7 15.6" full hd laptop quad core amd r...
# 35  acer aspire 3 a315-56 15.6" hd intel quad core...
# 36  dell inspiron 15 5567 gaming laptop 15.6" full...
# 37  lenovo ideapad 3i 14" full hd laptop quad core...
# 38  asus zenbook ux360ca 13.3" full hd touchscreen...
# 39  3 days delivery [refurbished] lenovo thinkpad ...
# 40  dell xps 15 7590 fast full hd led ultrabook la...
# 41  lenovo s340 15.6" full hd laptop intel pentium...
# 42  panasonic toughbook cf-c2 i5-4th gen 4-12gb 12...
# 43  msi bravo 15 15.6" 120hz gaming laptop ryzen 7...
# 44  asus vivobook 14" full hd quad core amd ryzen ...
# 45  acer swift 3 14" full hd laptop intel pentium™...
# 46  dell latitude 5404 rugged extreme laptop i7-46...
# 47  hp 15s-fq1510sa 15.6" full hd laptop intel qua...
# 48  notebook laptop siemens simatic filed pg m 6es...
# 49  asus zenbook pro 15 ux580gd-e2046t i9-8950hk 1...
# 50  hp 14-cf2504sa 14" full hd laptop intel quad c...
# 51  asus zenbook ux305ca ultrabook 13.3" full hd m...
# 52  hp 14-dk0011na 14" full hd quad core amd ryzen...
# 53  hp 14-cf2502sa 14" full hd laptop quad core in...
# 54  notebook laptop siemens simatic filed pg m 6es...
# 55  notebook laptop siemens simatic filed pg m 6es...
# 56  dell latitude 14 7414 rugged extreme laptop i7...
# 57  dell latitude e6410 business laptop pc core i5...
# 58  medion erazer p15609 gaming laptop 15.6" full ...
# 59  asus vivobook slim s330fa 13.3" full hd quad c...
#
#                                                  Link    Price Description  \
# 1   https://www.ebay.com.sg/itm/Dell-Latitude-5404...  1472.12
# 2   https://www.ebay.com.sg/itm/ASUS-Zenbook-UX31A...   649.49
# 3   https://www.ebay.com.sg/itm/Notebook-Laptop-SI...   1550.2
# 4   https://www.ebay.com.sg/itm/HP-14-CF1502sa-14-...  1037.08
# 5   https://www.ebay.com.sg/itm/HP-15s-eq1510sa-15...   932.73
# 6   https://www.ebay.com.sg/itm/Notebook-Laptop-SI...   1416.1
# 7   https://www.ebay.com.sg/itm/Acer-Nitro-5-AN515...  1115.62
# 8   https://www.ebay.com.sg/itm/Lenovo-YOGA-S730-1...   1074.2
# 9   https://www.ebay.com.sg/itm/Laptop-Computer-Le...   697.88
# 10  https://www.ebay.com.sg/itm/HP-14-cf2503sa-14-...   853.93
# 11  https://www.ebay.com.sg/itm/Dell-Latitude-14-7...  2656.59
# 12  https://www.ebay.com.sg/itm/Notebook-Laptop-SI...  1545.41
# 13  https://www.ebay.com.sg/itm/Linux-Laptop-Dell-...    449.0
# 14  https://www.ebay.com.sg/itm/Laptop-Computer-Le...   699.89
# 15  https://www.ebay.com.sg/itm/Lenovo-IdeaPad-L34...   1166.8
# 16  https://www.ebay.com.sg/itm/HP-Pavilion-14-ce3...   746.18
# 17  https://www.ebay.com.sg/itm/Laptop-Computer-HP...   816.55
# 18  https://www.ebay.com.sg/itm/LENOVO-IDEAPAD-5i-...   926.03
# 19  https://www.ebay.com.sg/itm/Asus-C302CA-Laptop...   539.19
# 20  https://www.ebay.com.sg/itm/Aftershock-Apex-15...   1350.0
# 21  https://www.ebay.com.sg/itm/MSI-GF75-Thin-17-3...  1815.04
# 22  https://www.ebay.com.sg/itm/Laptop-Black-Fusit...    253.2
# 23  https://www.ebay.com.sg/itm/HP-14s-dq1505sa-14...  1000.08
# 24  https://www.ebay.com.sg/itm/Dell-Latitude-14-7...  3187.91
# 25  https://www.ebay.com.sg/itm/LENOVO-Ideapad-530...   888.99
# 26  https://www.ebay.com.sg/itm/Apple-MacBook-Pro-...  1212.54
# 27  https://www.ebay.com.sg/itm/ASUS-ZenBook-UX305...   839.44
# 28  https://www.ebay.com.sg/itm/Notebook-Laptop-SI...  1578.94
# 29  https://www.ebay.com.sg/itm/ASUS-TP410U-14-inc...    899.0
# 30  https://www.ebay.com.sg/itm/Laptop-Computer-Le...   863.21
# 31  https://www.ebay.com.sg/itm/Retro-Notebook-Com...   614.65
# 32  https://www.ebay.com.sg/itm/HP-Pavilion-15-CW1...  1279.16
# 33  https://www.ebay.com.sg/itm/Acer-Acernote-Ligh...    110.0
# 34  https://www.ebay.com.sg/itm/HP-255-G7-15-6-Ful...   888.99
# 35  https://www.ebay.com.sg/itm/Acer-Aspire-3-A315...   839.46
# 36  https://www.ebay.com.sg/itm/Dell-Inspiron-15-5...  1208.57
# 37  https://www.ebay.com.sg/itm/LENOVO-IDEAPAD-3i-...   981.59
# 38  https://www.ebay.com.sg/itm/ASUS-ZenBook-UX360...   839.44
# 39  https://www.ebay.com.sg/itm/3-Days-Delivery-Re...    235.0
# 40  https://www.ebay.com.sg/itm/Dell-XPS-15-7590-F...  2696.09
# 41  https://www.ebay.com.sg/itm/Lenovo-S340-15-6-F...   545.98
# 42  https://www.ebay.com.sg/itm/Panasonic-Toughboo...    345.0
# 43  https://www.ebay.com.sg/itm/MSI-Bravo-15-15-6-...  1444.62
# 44  https://www.ebay.com.sg/itm/Asus-VivoBook-14-F...  1074.16
# 45  https://www.ebay.com.sg/itm/ACER-Swift-3-14-Fu...   611.17
# 46  https://www.ebay.com.sg/itm/Dell-Latitude-5404...  2006.99
# 47  https://www.ebay.com.sg/itm/HP-15s-fq1510sa-15...   888.99
# 48  https://www.ebay.com.sg/itm/Notebook-Laptop-SI...  1428.87
# 49  https://www.ebay.com.sg/itm/ASUS-ZenBook-Pro-1...  2984.76
# 50  https://www.ebay.com.sg/itm/HP-14-cf2504sa-14-...   851.95
# 51  https://www.ebay.com.sg/itm/ASUS-Zenbook-UX305...   545.72
# 52  https://www.ebay.com.sg/itm/HP-14-dk0011na-14-...   785.76
# 53  https://www.ebay.com.sg/itm/HP-14-cf2502sa-14-...   851.95
# 54  https://www.ebay.com.sg/itm/Notebook-Laptop-SI...  1575.75
# 55  https://www.ebay.com.sg/itm/Notebook-Laptop-SI...  1274.01
# 56  https://www.ebay.com.sg/itm/Dell-Latitude-14-7...  3055.08
# 57  https://www.ebay.com.sg/itm/Dell-Latitude-E641...    245.0
# 58  https://www.ebay.com.sg/itm/Medion-Erazer-P156...  1471.64
# 59  https://www.ebay.com.sg/itm/ASUS-VivoBook-Slim...   981.59
#
#          Condition Memory                    Model Operating system edition  \
# 1   remanufactured    8gb                     5404             professional
# 2   remanufactured    NaN             asus zenbook                      NaN
# 3   remanufactured    NaN                 filed pg                      NaN
# 4   remanufactured    8gb           hp 14-cf1502sa                      NaN
# 5   remanufactured    NaN          hp 15s-eq1510sa                      NaN
# 6   remanufactured    NaN               filed pg m                      NaN
# 7   remanufactured    NaN                      NaN                      NaN
# 8   remanufactured    NaN          lenovo yoga 730                      NaN
# 9   remanufactured    NaN                  i3-m380                      NaN
# 10  remanufactured    NaN           hp 14-cf2503sa                      NaN
# 11  remanufactured   16gb                     7414             professional
# 12  remanufactured    NaN                 filed pg                      NaN
# 13             NaN    NaN                      NaN                      NaN
# 14  remanufactured    NaN                 i5-3320m                      NaN
# 15  remanufactured    NaN      lenovo ideapad l340                      NaN
# 16  remanufactured    NaN  hp pavilion 14-ce3600sa                      NaN
# 17  remanufactured    NaN                 i5-3210m                      NaN
# 18  remanufactured    NaN        ideapad 5-14iil05                      NaN
# 19  remanufactured    NaN             c302ca-gu010                      NaN
# 20  remanufactured    NaN                  apex 15                      NaN
# 21  remanufactured    NaN                gf75 thin                      NaN
# 22  remanufactured    NaN                    s2110                      NaN
# 23  remanufactured    NaN          hp 14s-dq1505sa                      NaN
# 24  remanufactured   32gb                     7414             professional
# 25  remanufactured    NaN      lenovo ideapad 530s                      NaN
# 26  remanufactured    NaN                    a1398                      NaN
# 27  remanufactured    NaN           ux305fa-fc061h                      NaN
# 28  remanufactured    NaN               filed pg m                      NaN
# 29  remanufactured    NaN            asus vivobook                     home
# 30  remanufactured    NaN                 i5-4300m                      NaN
# 31  remanufactured    NaN                     4150                      NaN
# 32  remanufactured    NaN              15-cw1598sa                      NaN
# 33  remanufactured    NaN                   370pcx                      NaN
# 34  remanufactured    NaN                hp 255 g7                      NaN
# 35  remanufactured    NaN            acer aspire 3                      NaN
# 36  remanufactured    NaN                      NaN                      NaN
# 37  remanufactured    NaN        ideapad 3-14iil05                      NaN
# 38  remanufactured    NaN             asus zenbook                      NaN
# 39  remanufactured    NaN     lenovo thinkpad t430                      NaN
# 40  remanufactured    NaN         dell xps 15 7590                      NaN
# 41  remanufactured    NaN              lenovo s340                      NaN
# 42             NaN    NaN                      NaN                      NaN
# 43  remanufactured    NaN             msi bravo 15                      NaN
# 44  remanufactured    NaN            m413da-ek378t                      NaN
# 45  remanufactured    NaN             acer swift 3                      NaN
# 46  remanufactured   16gb                     5404             professional
# 47  remanufactured    NaN             15s-fq1510na                      NaN
# 48  remanufactured    NaN               filed pg m                      NaN
# 49  remanufactured    NaN           ux580gd-e2046t                      NaN
# 50  remanufactured    NaN              14-cf2504sa                      NaN
# 51  remanufactured    NaN             asus zenbook                      NaN
# 52  remanufactured    NaN              14-dk0011na                      NaN
# 53  remanufactured    NaN              14-cf2502sa                      NaN
# 54  remanufactured    NaN               filed pg m                      NaN
# 55  remanufactured    NaN               filed pg m                      NaN
# 56  remanufactured   32gb                     7414             professional
# 57             NaN    NaN                      NaN                      NaN
# 58  remanufactured    NaN           p15609-md61737                      NaN
# 59  remanufactured    NaN       asus vivobook slim                      NaN
#
#                                   Processor Ram size  ...  \
# 1                    intel core i7 4th gen.    16 gb  ...
# 2                    intel core i7 3rd gen.     4 gb  ...
# 3                            does not apply      NaN  ...
# 4                    intel core i7 8th gen.      NaN  ...
# 5                               amd ryzen 5     8 gb  ...
# 6                            does not apply      NaN  ...
# 7                            does not apply      NaN  ...
# 8                    intel core i7 8th gen.    16 gb  ...
# 9                                   i3 m380      NaN  ...
# 10                  intel core i5 10th gen.     4 gb  ...
# 11                           does not apply      NaN  ...
# 12                           does not apply      NaN  ...
# 13                                      NaN      NaN  ...
# 14                          intel celeron m      NaN  ...
# 15                   intel core i5 9th gen.     8 gb  ...
# 16                  intel core i3 10th gen.     8 gb  ...
# 17                                 i5 3210m      NaN  ...
# 18                  intel core i5 10th gen.     8 gb  ...
# 19                            intel m3-6y30     4 gb  ...
# 20                   intel core i7 8th gen.      NaN  ...
# 21                  intel core i7 10th gen.     8 gb  ...
# 22                           does not apply      NaN  ...
# 23                  intel core i7 10th gen.     8 gb  ...
# 24                           does not apply      NaN  ...
# 25                              amd ryzen 7     8 gb  ...
# 26                   intel core i7 4th gen.    16 gb  ...
# 27                             intel core m     8 gb  ...
# 28                           does not apply      NaN  ...
# 29               7th generation amd a6-9225     8 gb  ...
# 30                          intel celeron m      NaN  ...
# 31                           does not apply      NaN  ...
# 32                              amd ryzen 7    16 gb  ...
# 33                           does not apply      NaN  ...
# 34                              amd ryzen 5     8 gb  ...
# 35                  intel core i5 10th gen.     8 gb  ...
# 36                   intel core i7 7th gen.    16 gb  ...
# 37                  intel core i7 10th gen.     8 gb  ...
# 38                             intel core m     8 gb  ...
# 39                   intel core i5 2nd gen.     4 gb  ...
# 40  intel core i7-9750h 9th gen hexa 6 core    16 gb  ...
# 41                            intel pentium     4 gb  ...
# 42                                      NaN      NaN  ...
# 43                              amd ryzen 7     8 gb  ...
# 44                              amd ryzen 7      8gb  ...
# 45                            intel pentium     4 gb  ...
# 46                   intel core i7 4th gen.    16 gb  ...
# 47                  intel core i5 10th gen.     4 gb  ...
# 48                           does not apply      NaN  ...
# 49                   intel core i9 8th gen.    16 gb  ...
# 50                  intel core i5 10th gen.     4 gb  ...
# 51                       intel core m3-6y30     8 gb  ...
# 52                              amd ryzen 5     8 gb  ...
# 53                  intel core i5 10th gen.     4 gb  ...
# 54                           does not apply      NaN  ...
# 55                           does not apply      NaN  ...
# 56                           does not apply      NaN  ...
# 57                                      NaN      NaN  ...
# 58                   intel core i7 9th gen.     8 gb  ...
# 59                   intel core i7 8th gen.     8 gb  ...
#
#                       Ethernet                           Dimensions  \
# 1                          NaN                                  NaN
# 2                          NaN                                  NaN
# 3                          NaN                                  NaN
# 4                          NaN                                  NaN
# 5                          NaN                                  NaN
# 6                          NaN                                  NaN
# 7                          NaN                                  NaN
# 8                          NaN                                  NaN
# 9                          NaN                                  NaN
# 10                         NaN                                  NaN
# 11                         NaN                                  NaN
# 12                         NaN                                  NaN
# 13                         NaN                                  NaN
# 14                         NaN                                  NaN
# 15                         NaN                                  NaN
# 16                         NaN                                  NaN
# 17                         NaN                                  NaN
# 18                         NaN                                  NaN
# 19                         NaN                                  NaN
# 20                         NaN                                  NaN
# 21  killer e2500 ethernet port  18.9 x 396.1 x 259.4 mm (h x w x d)
# 22                         NaN                                  NaN
# 23                         NaN                                  NaN
# 24                         NaN                                  NaN
# 25                         NaN                                  NaN
# 26                         NaN                                  NaN
# 27                         NaN                                  NaN
# 28                         NaN                                  NaN
# 29                         NaN                                  NaN
# 30                         NaN                                  NaN
# 31                         NaN                                  NaN
# 32                         NaN                                  NaN
# 33                         NaN                                  NaN
# 34                         NaN                                  NaN
# 35                         NaN                                  NaN
# 36                         NaN                                  NaN
# 37                         NaN                                  NaN
# 38                         NaN                                  NaN
# 39                         NaN                                  NaN
# 40                         NaN                                  NaN
# 41                         NaN                                  NaN
# 42                         NaN                                  NaN
# 43                         NaN                                  NaN
# 44                         NaN                                  NaN
# 45                         NaN                                  NaN
# 46                         NaN                                  NaN
# 47                         NaN                                  NaN
# 48                         NaN                                  NaN
# 49                         NaN                                  NaN
# 50                         NaN                                  NaN
# 51                         NaN                                  NaN
# 52                         NaN                                  NaN
# 53                         NaN                                  NaN
# 54                         NaN                                  NaN
# 55                         NaN                                  NaN
# 56                         NaN                                  NaN
# 57                         NaN                                  NaN
# 58                         NaN                                  NaN
# 59                         NaN                                  NaN
#
#    Touchscreen Depth (mm)      Bluetooth                                Wifi  \
# 1          NaN        NaN            NaN                                 NaN
# 2          NaN        NaN            NaN                                 NaN
# 3          NaN        NaN            NaN                                 NaN
# 4          NaN        NaN            NaN                                 NaN
# 5          NaN        NaN            NaN                                 NaN
# 6          NaN        NaN            NaN                                 NaN
# 7          NaN        NaN            NaN                                 NaN
# 8          NaN        NaN            NaN                                 NaN
# 9          NaN        NaN            NaN                                 NaN
# 10         NaN        NaN            NaN                                 NaN
# 11         NaN        NaN            NaN                                 NaN
# 12         NaN        NaN            NaN                                 NaN
# 13         NaN        NaN            NaN                                 NaN
# 14         NaN        NaN            NaN                                 NaN
# 15         NaN        NaN            NaN                                 NaN
# 16         NaN        NaN            NaN                                 NaN
# 17         NaN        NaN            NaN                                 NaN
# 18         NaN        NaN            NaN                                 NaN
# 19         NaN        NaN            NaN                                 NaN
# 20         NaN        NaN            NaN                                 NaN
# 21          no      259.4  bluetooth 5.0  - wifi 6 ;- 2x2 ;- up to 1.73 gbps
# 22         NaN        NaN            NaN                                 NaN
# 23         NaN        NaN            NaN                                 NaN
# 24         NaN        NaN            NaN                                 NaN
# 25         NaN        NaN            NaN                                 NaN
# 26         NaN        NaN            NaN                                 NaN
# 27         NaN        NaN            NaN                                 NaN
# 28         NaN        NaN            NaN                                 NaN
# 29         NaN        NaN            NaN                                 NaN
# 30         NaN        NaN            NaN                                 NaN
# 31         NaN        NaN            NaN                                 NaN
# 32         NaN        NaN            NaN                                 NaN
# 33         NaN        NaN            NaN                                 NaN
# 34         NaN        NaN            NaN                                 NaN
# 35         NaN        NaN            NaN                                 NaN
# 36         NaN        NaN            NaN                                 NaN
# 37         NaN        NaN            NaN                                 NaN
# 38         NaN        NaN            NaN                                 NaN
# 39         NaN        NaN            NaN                                 NaN
# 40         NaN        NaN            NaN                                 NaN
# 41         NaN        NaN            NaN                                 NaN
# 42         NaN        NaN            NaN                                 NaN
# 43         NaN        NaN            NaN                                 NaN
# 44         NaN        NaN            NaN                                 NaN
# 45         NaN        NaN            NaN                                 NaN
# 46         NaN        NaN            NaN                                 NaN
# 47         NaN        NaN            NaN                                 NaN
# 48         NaN        NaN            NaN                                 NaN
# 49         NaN        NaN            NaN                                 NaN
# 50         NaN        NaN            NaN                                 NaN
# 51         NaN        NaN            NaN                                 NaN
# 52         NaN        NaN            NaN                                 NaN
# 53         NaN        NaN            NaN                                 NaN
# 54         NaN        NaN            NaN                                 NaN
# 55         NaN        NaN            NaN                                 NaN
# 56         NaN        NaN            NaN                                 NaN
# 57         NaN        NaN            NaN                                 NaN
# 58         NaN        NaN            NaN                                 NaN
# 59         NaN        NaN            NaN                                 NaN
#
#    Audio connections Storage capacity Compatible model  \
# 1                NaN              NaN              NaN
# 2                NaN              NaN              NaN
# 3                NaN              NaN              NaN
# 4                NaN              NaN              NaN
# 5                NaN              NaN              NaN
# 6                NaN              NaN              NaN
# 7                NaN              NaN              NaN
# 8                NaN              NaN              NaN
# 9                NaN              NaN              NaN
# 10               NaN              NaN              NaN
# 11               NaN              NaN              NaN
# 12               NaN              NaN              NaN
# 13               NaN              NaN              NaN
# 14               NaN              NaN              NaN
# 15               NaN              NaN              NaN
# 16               NaN              NaN              NaN
# 17               NaN              NaN              NaN
# 18               NaN              NaN              NaN
# 19               NaN              NaN              NaN
# 20               NaN              NaN              NaN
# 21       3.5 mm jack              NaN              NaN
# 22               NaN              NaN              NaN
# 23               NaN              NaN              NaN
# 24               NaN              NaN              NaN
# 25               NaN              NaN              NaN
# 26               NaN            256gb              NaN
# 27               NaN              NaN             asus
# 28               NaN              NaN              NaN
# 29               NaN              NaN              NaN
# 30               NaN              NaN              NaN
# 31               NaN              NaN              NaN
# 32               NaN              NaN              NaN
# 33               NaN              NaN              NaN
# 34               NaN              NaN              NaN
# 35               NaN              NaN              NaN
# 36               NaN              NaN              NaN
# 37               NaN              NaN              NaN
# 38               NaN              NaN             asus
# 39               NaN              NaN              NaN
# 40               NaN              NaN              NaN
# 41               NaN              NaN              NaN
# 42               NaN              NaN              NaN
# 43               NaN              NaN              NaN
# 44               NaN              NaN              NaN
# 45               NaN              NaN              NaN
# 46               NaN              NaN              NaN
# 47               NaN              NaN              NaN
# 48               NaN              NaN              NaN
# 49               NaN              NaN              NaN
# 50               NaN              NaN              NaN
# 51               NaN              NaN              NaN
# 52               NaN              NaN              NaN
# 53               NaN              NaN              NaN
# 54               NaN              NaN              NaN
# 55               NaN              NaN              NaN
# 56               NaN              NaN              NaN
# 57               NaN              NaN              NaN
# 58               NaN              NaN              NaN
# 59               NaN              NaN              NaN
#
#    Country/region of manufacture
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# 5                            NaN
# 6                            NaN
# 7                            NaN
# 8                            NaN
# 9                            NaN
# 10                           NaN
# 11                           NaN
# 12                           NaN
# 13                           NaN
# 14                           NaN
# 15                           NaN
# 16                           NaN
# 17                           NaN
# 18                           NaN
# 19                           NaN
# 20                           NaN
# 21                           NaN
# 22                           NaN
# 23                           NaN
# 24                           NaN
# 25                           NaN
# 26                           NaN
# 27                           NaN
# 28                           NaN
# 29                           NaN
# 30                           NaN
# 31                           NaN
# 32                           NaN
# 33                           NaN
# 34                           NaN
# 35                           NaN
# 36                           NaN
# 37                           NaN
# 38                           NaN
# 39                         china
# 40                           NaN
# 41                           NaN
# 42                           NaN
# 43                           NaN
# 44                           NaN
# 45                           NaN
# 46                           NaN
# 47                           NaN
# 48                           NaN
# 49                           NaN
# 50                           NaN
# 51                           NaN
# 52                           NaN
# 53                           NaN
# 54                           NaN
# 55                           NaN
# 56                           NaN
# 57                           NaN
# 58                           NaN
# 59                           NaN
#
# [59 rows x 83 columns]

# %%
df_reebelo = pd.DataFrame.from_dict(reebelo_storage, orient='index')
df_reebelo
# Out:
#                                                 Title  \
# 1        refurbished lenovo thinkpad x250 touch 240gb
# 2                    refurbished lenovo thinkpad t460
# 3   refurbished dell latitude e7280 12.5' / core i...
# 4   refurbished lenovo thinkpad yoga 370 (touchscr...
# 5                     refurbished dell latitude e7470
# 6               refurbished dell latitude e5470 256gb
# 7                   refurbished lenovo thinkpad t440p
# 8                refurbished dell latitude 7270 128gb
# 9                    refurbished acer travelmate p249
# 10                   refurbished lenovo thinkpad x240
# 11                      refurbished macbook pro a1502
# 12                    refurbished dell latitude e7250
# 13  refurbished lenovo thinkpad x280 8th 12.5'' / ...
# 14        refurbished dell latitude e7470 touchscreen
# 15                    refurbished hp elitebook 840 g2
# 16                  refurbished lenovo thinkpad t540p
# 17                    refurbished hp elitebook 820 g2
# 18  brand new hp elitebook 830 g7 13.3" i5 10210u ...
# 19                  refurbished lenovo thinkpad t450s
# 20  refurbished hp elitebook 840 g3 / 14'' / core ...
# 21                refurbished dell inspiron 15 (3576)
# 22  refurbished dell latitude e7270 12.5'' / core ...
# 23  refurbished lenovo thinkpad x1 yoga 1st gen (t...
# 24                  refurbished lenovo thinkpad t460s
# 25                   refurbished lenovo thinkpad x260
# 26  refurbished lenovo thinkpad x1 yoga 1st gen ul...
# 27                    refurbished dell latitude e7450
# 28    refurbished asus zenbook ux331un 13 touch 512gb
# 29                    refurbished dell latitude e7440
# 30                   refurbished lenovo thinkpad x260
# 31  refurbished lenovo thinkpad x1 carbon 6th gen ...
# 32  refurbished dell latitude e5470 / 14" / core i...
# 33                  refurbished lenovo thinkpad t440p
# 34                  refurbished fujitsu lifebook e546
# 35                   refurbished lenovo thinkpad x240
# 36       refurbished lenovo thinkpad t460 touch 256gb
# 37                   refurbished lenovo thinkpad t460
# 38                   refurbished lenovo thinkpad l560
# 39                         refurbished hp zbook 15 g3
# 40  refurbished dell latitude e7280 12.5' / core i...
# 41                  refurbished lenovo thinkpad t440s
# 42       refurbished hp elitebook folio 1040 g3 256gb
# 43  refurbished hp elitebook 820 g3 / 12.5'' / cor...
# 44              refurbished lenovo thinkpad p50 256gb
# 45               refurbished dell latitude 5480 256gb
#
#                                                  Link  Price Description  \
# 1   https://www.reebelo.com/collections/all/produc...    649
# 2   https://www.reebelo.com/collections/all/produc...    643
# 3   https://www.reebelo.com/collections/all/produc...    649
# 4   https://www.reebelo.com/collections/all/produc...  1,029
# 5   https://www.reebelo.com/collections/all/produc...    809
# 6   https://www.reebelo.com/collections/all/produc...    849
# 7   https://www.reebelo.com/collections/all/produc...    528
# 8   https://www.reebelo.com/collections/all/produc...    649
# 9   https://www.reebelo.com/collections/all/produc...    575
# 10  https://www.reebelo.com/collections/all/produc...    459
# 11  https://www.reebelo.com/collections/all/produc...  1,269
# 12  https://www.reebelo.com/collections/all/produc...    528
# 13  https://www.reebelo.com/collections/all/produc...    868
# 14  https://www.reebelo.com/collections/all/produc...    919
# 15  https://www.reebelo.com/collections/all/produc...    574
# 16  https://www.reebelo.com/collections/all/produc...    459
# 17  https://www.reebelo.com/collections/all/produc...    574
# 18  https://www.reebelo.com/collections/all/produc...  1,110
# 19  https://www.reebelo.com/collections/all/produc...    620
# 20  https://www.reebelo.com/collections/all/produc...    469
# 21  https://www.reebelo.com/collections/all/produc...    719
# 22  https://www.reebelo.com/collections/all/produc...    569
# 23  https://www.reebelo.com/collections/all/produc...    929
# 24  https://www.reebelo.com/collections/all/produc...    689
# 25  https://www.reebelo.com/collections/all/produc...    597
# 26  https://www.reebelo.com/collections/all/produc...    849
# 27  https://www.reebelo.com/collections/all/produc...    758
# 28  https://www.reebelo.com/collections/all/produc...  1,299
# 29  https://www.reebelo.com/collections/all/produc...    597
# 30  https://www.reebelo.com/collections/all/produc...    540
# 31  https://www.reebelo.com/collections/all/produc...  1,068
# 32  https://www.reebelo.com/collections/all/produc...    499
# 33  https://www.reebelo.com/collections/all/produc...    439
# 34  https://www.reebelo.com/collections/all/produc...    429
# 35  https://www.reebelo.com/collections/all/produc...    459
# 36  https://www.reebelo.com/collections/all/produc...    849
# 37  https://www.reebelo.com/collections/all/produc...    586
# 38  https://www.reebelo.com/collections/all/produc...    688
# 39  https://www.reebelo.com/collections/all/produc...  1,529
# 40  https://www.reebelo.com/collections/all/produc...    599
# 41  https://www.reebelo.com/collections/all/produc...    643
# 42  https://www.reebelo.com/collections/all/produc...    949
# 43  https://www.reebelo.com/collections/all/produc...    399
# 44  https://www.reebelo.com/collections/all/produc...  1,149
# 45  https://www.reebelo.com/collections/all/produc...    649
#
#    Condition Keyboard language Keyboard type Screen size (inches)  \
# 1       mint      english (us)        qwerty                   13
# 2        NaN               NaN           NaN                  NaN
# 3        NaN               NaN           NaN                  NaN
# 4        NaN               NaN           NaN                  NaN
# 5        NaN              1399           NaN         english (us)
# 6       mint      english (us)        qwerty                   14
# 7        NaN               NaN           NaN                  NaN
# 8       mint      english (us)        qwerty                   13
# 9        NaN               NaN      standard                   14
# 10       NaN               NaN           NaN                  NaN
# 11       NaN               NaN           NaN                  NaN
# 12       NaN               NaN           NaN                  NaN
# 13       NaN               NaN           NaN                  NaN
# 14       NaN               NaN           NaN                  NaN
# 15       NaN               NaN           NaN                  NaN
# 16       NaN               NaN           NaN                  NaN
# 17       NaN               NaN           NaN                  NaN
# 18       NaN               NaN           NaN                  NaN
# 19       NaN               NaN           NaN                  NaN
# 20       NaN               NaN           NaN                  NaN
# 21       NaN      english (us)        qwerty                   15
# 22       NaN               NaN           NaN                  NaN
# 23       NaN               NaN           NaN                  NaN
# 24       NaN               NaN           NaN                  NaN
# 25       NaN               NaN           NaN                  NaN
# 26       NaN               NaN           NaN                  NaN
# 27       NaN               NaN           NaN                  NaN
# 28      mint      english (us)        qwerty                   13
# 29       NaN               NaN           NaN                  NaN
# 30       NaN               NaN           NaN                  NaN
# 31       NaN               NaN           NaN                  NaN
# 32       NaN               NaN           NaN                  NaN
# 33       NaN               NaN           NaN                  NaN
# 34       NaN               NaN           NaN                  NaN
# 35       NaN               NaN           NaN                  NaN
# 36      mint      english (us)        qwerty                   14
# 37       NaN               NaN           NaN                  NaN
# 38       NaN               NaN           NaN                  NaN
# 39       NaN               NaN           NaN                  NaN
# 40       NaN               NaN           NaN                  NaN
# 41       NaN               NaN           NaN                  NaN
# 42      mint      english (us)        qwerty                   14
# 43       NaN               NaN           NaN                  NaN
# 44      mint      english (us)        qwerty                   15
# 45      mint      english (us)        qwerty                   14
#
#                Resolution Storage (gb)  ...             Weight  \
# 1                                  240  ...                NaN
# 2                     NaN          NaN  ...                NaN
# 3                     NaN          NaN  ...            2.6 lbs
# 4                     NaN          NaN  ...                NaN
# 5                  qwerty           14  ...                NaN
# 6                                  256  ...                NaN
# 7                     NaN          NaN  ...                NaN
# 8                                  128  ...                NaN
# 9                1366*768          500  ...                NaN
# 10                    NaN          NaN  ...                NaN
# 11                    NaN          NaN  ...                NaN
# 12                    NaN          NaN  ...                NaN
# 13  1920 x 1080 (full hd)          NaN  ...            2.8 lbs
# 14                    NaN          NaN  ...                NaN
# 15                    NaN          NaN  ...                NaN
# 16                    NaN          NaN  ...                NaN
# 17                    NaN          NaN  ...                NaN
# 18                    NaN          NaN  ...                NaN
# 19                    NaN          NaN  ...                NaN
# 20                    NaN          NaN  ...  2.978lbs / 3.4ibs
# 21            1920 x 1080          240  ...                NaN
# 22                    NaN          NaN  ...           2.78 lbs
# 23                    NaN          NaN  ...                NaN
# 24                    NaN          NaN  ...                NaN
# 25                    NaN          NaN  ...                NaN
# 26  1920 x 1080 (full hd)          NaN  ...              3 lbs
# 27                    NaN          NaN  ...                NaN
# 28                                 512  ...                NaN
# 29                    NaN          NaN  ...                NaN
# 30                    NaN          NaN  ...                NaN
# 31  1920 x 1080 (full hd)          NaN  ...           2.49 lbs
# 32                    NaN          NaN  ...           3.88 lbs
# 33                    NaN          NaN  ...                NaN
# 34                    NaN          NaN  ...                NaN
# 35                    NaN          NaN  ...                NaN
# 36                                 256  ...                NaN
# 37                    NaN          NaN  ...                NaN
# 38                    NaN          NaN  ...                NaN
# 39                    NaN          NaN  ...                NaN
# 40                    NaN          NaN  ...            2.6 lbs
# 41                    NaN          NaN  ...                NaN
# 42                                 256  ...                NaN
# 43                    NaN          NaN  ...  2.978lbs / 3.4ibs
# 44                                 256  ...                NaN
# 45                                 256  ...                NaN
#
#                    Operating system   Ram              Storage  \
# 1                               NaN   NaN                  NaN
# 2                               NaN   NaN                  NaN
# 3   microsoft windows 10 pro 64-bit   NaN                  NaN
# 4                               NaN   8gb            256gb ssd
# 5                               NaN   NaN                  NaN
# 6                               NaN   NaN                  NaN
# 7                               NaN   NaN                  NaN
# 8                               NaN   NaN                  NaN
# 9                               NaN   NaN                  NaN
# 10                              NaN   NaN                  NaN
# 11                              NaN   NaN                  NaN
# 12                              NaN   NaN                  NaN
# 13  microsoft windows 10 pro 64-bit   NaN                  NaN
# 14                              NaN   NaN                  NaN
# 15                              NaN   NaN                  NaN
# 16                              NaN   NaN                  NaN
# 17                              NaN   NaN                  NaN
# 18                              NaN   NaN                  NaN
# 19                              NaN   NaN                  NaN
# 20  microsoft windows 10 pro 64-bit   NaN                  NaN
# 21                              NaN   NaN                  NaN
# 22  microsoft windows 10 pro 64-bit   NaN                  NaN
# 23                              NaN   8gb            256gb ssd
# 24                              NaN   NaN                  NaN
# 25                              NaN   NaN                  NaN
# 26  microsoft windows 10 pro 64-bit   NaN                  NaN
# 27                              NaN   NaN                  NaN
# 28                              NaN   NaN                  NaN
# 29                              NaN   NaN                  NaN
# 30                              NaN   NaN                  NaN
# 31  microsoft windows 10 pro 64-bit   NaN                  NaN
# 32  microsoft windows 10 pro 64-bit   NaN                  NaN
# 33                              NaN   NaN                  NaN
# 34                              NaN   8gb            128gb ssd
# 35                              NaN   NaN                  NaN
# 36                              NaN   NaN                  NaN
# 37                              NaN   NaN                  NaN
# 38                              NaN   NaN                  NaN
# 39                              NaN  32gb  512gb ssd + 1tb hdd
# 40  microsoft windows 10 pro 64-bit   NaN                  NaN
# 41                              NaN   NaN                  NaN
# 42                              NaN   NaN                  NaN
# 43  microsoft windows 10 pro 64-bit   NaN                  NaN
# 44                              NaN   NaN                  NaN
# 45                              NaN   NaN                  NaN
#
#                         Ram installed size Display resolution  \
# 1                   NaN                NaN                NaN
# 2                   NaN                NaN                NaN
# 3                   NaN                NaN                NaN
# 4                   NaN                NaN                NaN
# 5   dell latitude e7470                NaN                NaN
# 6                   NaN                NaN                NaN
# 7                   NaN                NaN                NaN
# 8                   NaN                NaN                NaN
# 9                    na                NaN                NaN
# 10                  NaN                NaN                NaN
# 11                  NaN                NaN                NaN
# 12                  NaN                NaN                NaN
# 13                  NaN                8gb            full hd
# 14                  NaN                NaN                NaN
# 15                  NaN                NaN                NaN
# 16                  NaN                NaN                NaN
# 17                  NaN                NaN                NaN
# 18                  NaN                NaN                NaN
# 19                  NaN                NaN                NaN
# 20                  NaN                NaN    1366 x 768 (hd)
# 21                  NaN                NaN                NaN
# 22                  NaN                NaN                NaN
# 23                  NaN                NaN                NaN
# 24                  NaN                NaN                NaN
# 25                  NaN                NaN                NaN
# 26                  NaN             2x 8gb            full hd
# 27                  NaN                NaN                NaN
# 28                  NaN                NaN                NaN
# 29                  NaN                NaN                NaN
# 30                  NaN                NaN                NaN
# 31                  NaN                8gb            full hd
# 32                  NaN                NaN                NaN
# 33                  NaN                NaN                NaN
# 34                  NaN                NaN                NaN
# 35                  NaN                NaN                NaN
# 36                  NaN                NaN                NaN
# 37                  NaN                NaN                NaN
# 38                  NaN                NaN                NaN
# 39                  NaN                NaN                NaN
# 40                  NaN                NaN                NaN
# 41                  NaN                NaN                NaN
# 42                  NaN                NaN                NaN
# 43                  NaN                NaN    1366 x 768 (hd)
# 44                  NaN                NaN                NaN
# 45                  NaN                NaN                NaN
#
#                                              Features  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  hd standard-viewing angle (sva) edp anti-glare...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
#
#                                                   Gpu  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39  nvidia quadro m2000m with 4 gb dedicated gddr5...
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
#
#        Speakers, stereo microphone data link protocol
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43  bluetooth 4.2, ethernet,\nfast ethernet, gigab...
# 44                                                NaN
# 45                                                NaN
#
# [45 rows x 54 columns]

# %%
df_ebay.to_excel("ebay.xlsx")

# %%
df_reebelo.to_excel("reebelo.xlsx")

# %%
# # Lazada example
# driver = webdriver.Chrome(executable_path=os.getenv("CHROMEDRIVER_PATH"))
# driver.get('https://www.lazada.sg/')

# # Search for laptop
# search_bar = driver.find_element_by_id("q")
# search_bar.send_keys("laptop", Keys.ENTER)

# # Filter by Refurbished items
# used_checkbox = driver.find_element_by_xpath("//span[contains(text(), 'Refurbish')]")
# used_checkbox.click()

# link_container = driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[3]').find_elements_by_tag_name("a")
# links = []
# for link in link_container:
#     links.append(link.get_attribute("href"))
# links = list(set(links))

# storage = {}
# for i in range(len(links)):
#     driver.get(links[i])
#     try:
#         product_title = driver.find_element_by_class_name("pdp-mod-product-badge-title").text
#         specs = driver.find_element_by_class_name("specification-keys").find_elements_by_tag_name("li")
#         storage[i] = {"title": product_title}
#         for spec in specs:
#             spec_title = spec.find_element_by_class_name("key-title").text
#             storage[i][spec_title] = spec.find_element_by_class_name("key-value").text 
#     except NoSuchElementException:
#         pass
